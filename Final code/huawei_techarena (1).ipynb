# %%
# !pip install -q cupy-cuda12x

# %%
import csv

file_path = "/content/Topic 2 Information on the beam position and beam width of multiple beams.csv"

with open(file_path, "r") as f:
    reader = csv.reader(f)
    # Read the header row
    header = next(reader)
    print("CSV Headers:")
    print(header)
# Out:
# CSV Headers:
# ['theta(deg)', 'phi(deg)', 'Beam Width in azimuth(deg)', 'Beam Width in elevation(deg)']

# %%
"""
LEO Beamforming – Task A & Task B (GPU-ready: CuPy or NumPy)
------------------------------------------------------------
Reference Python implementation for the Huawei Tech Arena SUB-TOPIC 2 tasks.
"""

from __future__ import annotations
import csv
from dataclasses import dataclass
import typing as t

# ----------------------------
# Backend selection (CuPy -> NumPy fallback)
# ----------------------------
try:
    import cupy as cp
    xp = cp
    BACKEND = "cupy"
except Exception:  # CuPy not available
    import numpy as np
    xp = np
    BACKEND = "numpy"

from matplotlib import pyplot as plt
from matplotlib.patches import Ellipse

# ----------------------------
# Helpers for CPU/GPU interop
# ----------------------------
def to_cpu(a):
    if BACKEND == "cupy":
        return cp.asnumpy(a)
    return a

def as_float(x) -> float:
    if BACKEND == "cupy":
        return float(cp.asnumpy(x))
    return float(x)

def as_int(x) -> int:
    if BACKEND == "cupy":
        return int(cp.asnumpy(x))
    return int(x)

# ----------------------------
# Geometry & steering utilities
# ----------------------------

TWOPI = 2.0 * (xp.pi if hasattr(xp, "pi") else __import__("math").pi)

@dataclass
class ArraySpec:
    N: int = 100
    d: float = 0.5
    wavelength: float = 1.0

    @property
    def k(self) -> float:
        return float(2.0 * __import__("math").pi / self.wavelength)

    @property
    def M(self) -> int:
        return self.N * self.N


def grid_indices(N: int):
    g = xp.arange(N, dtype=xp.float32) - (N - 1) / 2.0
    m, n = xp.meshgrid(g, g, indexing="ij")
    return m, n


def direction_cosines(theta_deg: float, phi_deg: float) -> tuple[float, float]:
    th = xp.deg2rad(xp.float32(theta_deg))
    ph = xp.deg2rad(xp.float32(phi_deg))
    u = xp.sin(th) * xp.cos(ph)
    v = xp.sin(th) * xp.sin(ph)
    return as_float(u), as_float(v)


def steering_phases(spec: ArraySpec, theta_deg: float, phi_deg: float):
    u, v = direction_cosines(theta_deg, phi_deg)
    m, n = grid_indices(spec.N)
    phase = -1j * xp.float32(spec.k * spec.d) * (m * xp.float32(u) + n * xp.float32(v))
    return xp.exp(phase, dtype=xp.complex64) if BACKEND == "cupy" else xp.exp(phase)

# ----------------------------
# Windows (amplitude tapers)
# ----------------------------

def window_1d(N: int, kind: str = "uniform"):
    if kind.lower() == "hann":
        x = xp.arange(N, dtype=xp.float32)
        w = xp.float32(0.5) * (1 - xp.cos(TWOPI * x / xp.float32(N - 1)))
    elif kind.lower() == "uniform":
        w = xp.ones(N, dtype=xp.float32)
    else:
        raise ValueError(f"Unsupported window kind: {kind}")
    return w / xp.linalg.norm(w)


def window_2d(N: int, kind: str = "uniform"):
    w = window_1d(N, kind)
    W = xp.outer(w, w)
    return W / xp.linalg.norm(W)

# ----------------------------
# Task A – beam weight design
# ----------------------------

@dataclass
class BeamSpec:
    theta_deg: float
    phi_deg: float
    window: str = "hann"

def design_beam_weights(spec: ArraySpec, beam: BeamSpec, amp_override=None):
    phase = steering_phases(spec, beam.theta_deg, beam.phi_deg)
    amp = amp_override if amp_override is not None else window_2d(spec.N, beam.window)
    amp = amp.astype(xp.float32, copy=False)
    w = amp * xp.conj(phase).astype(xp.complex64 if BACKEND == "cupy" else phase.dtype)
    return w / xp.linalg.norm(w)

# ----------------------------
# Field evaluation & metrics
# ----------------------------

def array_factor(spec: ArraySpec, w, theta_deg_vec, phi_deg: float):
    m, n = grid_indices(spec.N)
    th = xp.deg2rad(xp.asarray(theta_deg_vec, dtype=xp.float32))[None, :]
    ph = xp.deg2rad(xp.float32(phi_deg))
    u = xp.sin(th) * xp.cos(ph)
    v = xp.sin(th) * xp.sin(ph)
    expo = 1j * xp.float32(spec.k * spec.d) * (m[..., None] * u + n[..., None] * v)
    a = xp.exp(expo, dtype=xp.complex64) if BACKEND == "cupy" else xp.exp(expo)
    af = xp.tensordot(w, a, axes=([0, 1], [0, 1]))
    return af

def db(x, ref: float = 1.0):
    mag = xp.abs(x)
    return 20.0 * xp.log10(xp.maximum(mag / ref, 1e-12))

def half_power_beamwidth(theta_deg_vec, pattern_db_vec) -> float:
    peak = xp.max(pattern_db_vec)
    mask = pattern_db_vec >= (peak - 3.0)
    if not bool(xp.any(mask)):
        return float("nan")
    idx = xp.where(mask)[0]
    th = theta_deg_vec
    return as_float(th[idx[-1]] - th[idx[0]])

@dataclass
class BeamReport:
    mainlobe_gain_db: float
    hpbw_deg: float
    peak_sll_db: float

def _smooth_1d_uniform(patt, k: int = 5):
    if k <= 1 or patt.size < k:
        return patt
    kernel = xp.ones(k, dtype=patt.dtype) / k
    return xp.convolve(patt, kernel, mode="same")

def analyze_beam(spec: ArraySpec, w, cut_phi_deg: float) -> BeamReport:
    th = xp.linspace(-60.0, 60.0, 4801, dtype=xp.float32)
    af = array_factor(spec, w, th, cut_phi_deg)
    mag = xp.abs(af)

    peak_idx = as_int(xp.argmax(mag))
    peak_abs = as_float(mag[peak_idx])
    mainlobe_gain_db = 20.0 * __import__("math").log10(max(peak_abs, 1e-12))

    patt = xp.maximum(mag / max(peak_abs, 1e-12), 1e-12)
    patt_s = _smooth_1d_uniform(patt, k=5)
    patt_db = 20.0 * xp.log10(patt_s)

    left = peak_idx
    while left > 0 and as_float(patt_db[left]) >= -3.0:
        left -= 1
    right = peak_idx
    while right < patt_db.size - 1 and as_float(patt_db[right]) >= -3.0:
        right += 1
    hpbw_deg = float(as_float(th[right] - th[left]) if right > left else float("nan"))

    dp = xp.diff(patt_s)
    min_left = max(1, peak_idx - 1)
    while min_left > 1 and not (as_float(dp[min_left - 1]) < 0.0 and as_float(dp[min_left]) > 0.0):
        min_left -= 1
    min_right = min(patt_db.size - 2, peak_idx + 1)
    while min_right < dp.size - 1 and not (as_float(dp[min_right - 1]) < 0.0 and as_float(dp[min_right]) > 0.0):
        min_right += 1

    credible = (min_left < peak_idx < min_right) and (right > left)
    if not credible or (peak_idx - min_left) < 3 or (min_right - peak_idx) < 3:
        exclude_half = max(3, int(0.75 * (right - left)))
        min_left = max(1, peak_idx - exclude_half)
        min_right = min(patt_db.size - 2, peak_idx + exclude_half)

    parts = []
    if min_left > 0:
        parts.append(patt_db[:min_left])
    if min_right < patt_db.size - 1:
        parts.append(patt_db[min_right + 1:])
    if parts:
        sll_rel = xp.max(xp.concatenate(parts))
        peak_sll_db = as_float(sll_rel)
    else:
        peak_sll_db = float("-inf")

    return BeamReport(mainlobe_gain_db=mainlobe_gain_db,
                      hpbw_deg=hpbw_deg,
                      peak_sll_db=peak_sll_db)

# ----------------------------
# Target-HPBW Gaussian taper (separable)
# ----------------------------

def gaussian_1d(N: int, sigma: float):
    g = xp.arange(N, dtype=xp.float32) - (N - 1) / 2.0
    w = xp.exp(-0.5 * (g / max(sigma, 1e-9))**2)
    return w / xp.linalg.norm(w)

def gaussian_2d(N: int, sigma_x: float, sigma_y: float):
    wx = gaussian_1d(N, sigma_x)
    wy = gaussian_1d(N, sigma_y)
    W = xp.outer(wx, wy)
    return W / xp.linalg.norm(W)

def _array_factor_phi_sweep(spec: ArraySpec, w, theta_deg: float, phi_vec_deg):
    m, n = grid_indices(spec.N)
    th = xp.deg2rad(xp.float32(theta_deg))
    ph = xp.deg2rad(xp.asarray(phi_vec_deg, dtype=xp.float32))[None, :]
    u = xp.sin(th) * xp.cos(ph)
    v = xp.sin(th) * xp.sin(ph)
    expo = 1j * xp.float32(spec.k * spec.d) * (m[..., None] * u + n[..., None] * v)
    a = xp.exp(expo, dtype=xp.complex64) if BACKEND == "cupy" else xp.exp(expo)
    af = xp.tensordot(w, a, axes=([0, 1], [0, 1]))
    return af

def _hpbw_from_cut(spec: ArraySpec, w, theta0_deg: float, phi0_deg: float,
                   vary: str = "theta", span_deg: float = 4.0) -> float:
    if vary == "theta":
        th = xp.linspace(theta0_deg - span_deg, theta0_deg + span_deg, 801, dtype=xp.float32)
        af = array_factor(spec, w, th, phi0_deg)
        patt_db = 20 * xp.log10(xp.maximum(xp.abs(af) / xp.max(xp.abs(af)), 1e-12))
        return half_power_beamwidth(th, patt_db)
    else:
        ph = xp.linspace(phi0_deg - span_deg, phi0_deg + span_deg, 801, dtype=xp.float32)
        af = _array_factor_phi_sweep(spec, w, theta0_deg, ph)
        patt_db = 20 * xp.log10(xp.maximum(xp.abs(af) / xp.max(xp.abs(af)), 1e-12))
        return half_power_beamwidth(ph, patt_db)

def _tune_sigma_for_hpbw(spec: ArraySpec, theta0: float, phi0: float,
                         target_bw_deg: float, axis: str,
                         base_phase,
                         other_sigma: float,
                         iters: int = 20) -> float:
    lo, hi = 0.5, spec.N / 2
    best = (None, float("inf"))
    for _ in range(iters):
        mid = 0.5 * (lo + hi)
        if axis == "elev":
            amp = gaussian_2d(spec.N, other_sigma, mid)
        else:
            amp = gaussian_2d(spec.N, mid, other_sigma)
        w_try = (amp * xp.conj(base_phase)) / xp.linalg.norm(amp)
        if axis == "elev":
            bw = _hpbw_from_cut(spec, w_try, theta0, phi0, vary="theta", span_deg=max(3.0, target_bw_deg * 2.0))
        else:
            bw = _hpbw_from_cut(spec, w_try, theta0, phi0, vary="phi", span_deg=max(3.0, target_bw_deg * 2.0))
        err = bw - target_bw_deg
        if abs(err) < best[1]:
            best = (mid, abs(err))
        if err < 0:
            lo = mid
        else:
            hi = mid
    return best[0] if best[0] is not None else (lo + hi) / 2

def build_amp_for_target_widths(spec: ArraySpec, beam: BeamSpec,
                                az_bw_deg: float, el_bw_deg: float):
    base_phase = steering_phases(spec, beam.theta_deg, beam.phi_deg)
    sigma_x = spec.N / 6
    sigma_y = spec.N / 6
    for _ in range(6):
        sigma_y = _tune_sigma_for_hpbw(spec, beam.theta_deg, beam.phi_deg, el_bw_deg,
                                       axis="elev", base_phase=base_phase, other_sigma=sigma_x)
        sigma_x = _tune_sigma_for_hpbw(spec, beam.theta_deg, beam.phi_deg, az_bw_deg,
                                       axis="az",   base_phase=base_phase, other_sigma=sigma_y)
    return gaussian_2d(spec.N, sigma_x, sigma_y)

# ----------------------------
# Task B – thinning (sparsity)
# ----------------------------

def _weighted_sample_without_replacement(p_flat: "xp.ndarray", k: int):
    k = int(max(0, min(k, p_flat.size)))
    if k == 0:
        return xp.asarray([], dtype=xp.int64)
    p = p_flat.astype(xp.float32, copy=False).ravel()
    p = p / (p.sum() + xp.finfo(xp.float32).eps)
    u = xp.random.random(p.shape, dtype=xp.float32)
    g = -xp.log(-xp.log(xp.maximum(u, xp.float32(1e-12))))
    scores = xp.log(p + xp.float32(1e-20)) + g
    idx = xp.argpartition(scores, -k)[-k:]
    return idx

def make_thinning_mask(N: int, frac_off: float, strategy: str = "edge_preserving", seed: int | None = 0):
    if seed is not None:
        xp.random.seed(int(seed))

    M = xp.ones((N, N), dtype=bool)
    total = N * N
    off = int(round(frac_off * total))
    off = max(0, min(off, total))

    yy, xx = xp.meshgrid(xp.linspace(-1, 1, N, dtype=xp.float32),
                         xp.linspace(-1, 1, N, dtype=xp.float32), indexing="ij")
    r = xp.hypot(xx, yy)

    if strategy == "edge_preserving":
        order = xp.argsort(r.ravel())
        idx = order[:off]
        M.ravel()[idx] = False

    elif strategy == "random_uniform":
        idx = xp.random.choice(total, size=off, replace=False)
        M.ravel()[idx] = False

    elif strategy == "blue_noise_like":
        beta = 4.0
        p = xp.exp(-beta * r**2)
        p = p / p.sum()
        idx = _weighted_sample_without_replacement(p.ravel(), off)
        M.ravel()[idx] = False

    else:
        raise ValueError("Unknown thinning strategy")

    return M.astype(xp.float32)  # 1=active, 0=off

def apply_thinning(w, mask):
    w2 = w * mask.astype(w.dtype, copy=False)
    nrm = xp.linalg.norm(w2)
    if as_float(nrm) == 0.0:
        raise ValueError("All elements were deactivated!")
    return w2 / nrm

def retaper_active_elements(w_thinned, mask, amp_target, w_phase_ref=None):
    ref = w_phase_ref if w_phase_ref is not None else w_thinned
    mask_f = mask.astype(xp.float32, copy=False)
    w_retapered = (amp_target * mask_f) * xp.exp(1j * xp.angle(ref))
    nrm = xp.linalg.norm(w_retapered)
    if as_float(nrm) == 0.0:
        raise ValueError("All elements were deactivated after retapering!")
    return w_retapered / nrm

# ---------- NEW: visualize the 70%/30% mask ----------
def show_array_mask(mask, title="Active (1) / Off (0) elements", figsize=(5, 5)):
    m = to_cpu(mask)
    plt.figure(figsize=figsize)
    plt.imshow(m, origin="lower", interpolation="nearest")
    plt.colorbar(label="1=active, 0=off")
    plt.title(title)
    plt.xlabel("n (columns)")
    plt.ylabel("m (rows)")
    plt.tight_layout()
# -----------------------------------------------------

@dataclass
class ThinningResult:
    mask: object
    weights: object
    frac_off: float
    mainlobe_loss_db: float
    hpbw_change_pct: float
    sll_change_db: float

def task_b_thin(spec: ArraySpec, w_base, cut_phi_deg: float,
                frac_off: float = 0.30, strategy: str = "edge_preserving", seed: int | None = 0,
                amp_target=None, theta0_deg: float | None = None, phi0_deg: float | None = None) -> ThinningResult:
    mask = make_thinning_mask(spec.N, frac_off, strategy=strategy, seed=seed)
    w_thin = apply_thinning(w_base, mask)
    if amp_target is not None:
        w_thin = retaper_active_elements(w_thin, mask, amp_target, w_phase_ref=w_base)

    if theta0_deg is not None and phi0_deg is not None:
        gA = gain_at_direction_db(spec, w_base, theta0_deg, phi0_deg)
        gB = gain_at_direction_db(spec, w_thin, theta0_deg, phi0_deg)
        mainlobe_loss_db = gB - gA
        rep0 = analyze_beam(spec, w_base, cut_phi_deg)
        rep1 = analyze_beam(spec, w_thin, cut_phi_deg)
        hpbw_change_pct = 100.0 * (rep1.hpbw_deg - rep0.hpbw_deg) / rep0.hpbw_deg if (rep0.hpbw_deg == rep0.hpbw_deg) else float("nan")
        sll_change_db = rep1.peak_sll_db - rep0.peak_sll_db
    else:
        rep0 = analyze_beam(spec, w_base, cut_phi_deg)
        rep1 = analyze_beam(spec, w_thin, cut_phi_deg)
        mainlobe_loss_db = rep1.mainlobe_gain_db - rep0.mainlobe_gain_db
        hpbw_change_pct = 100.0 * (rep1.hpbw_deg - rep0.hpbw_deg) / rep0.hpbw_deg if (rep0.hpbw_deg == rep0.hpbw_deg) else float("nan")
        sll_change_db = rep1.peak_sll_db - rep0.peak_sll_db

    return ThinningResult(mask, w_thin, frac_off, mainlobe_loss_db, hpbw_change_pct, sll_change_db)

# ----------------------------
# Sat-to-ground geometry & footprint visualization
# ----------------------------

@dataclass
class SatSpec:
    h_km: float = 550.0
    plane: str = "xy"   # "xy" top-down (default), or "xz"/"yz"

def beam_direction_vector(theta_deg: float, phi_deg: float):
    th = xp.deg2rad(xp.float32(theta_deg)); ph = xp.deg2rad(xp.float32(phi_deg))
    dx = xp.sin(th)*xp.cos(ph)
    dy = xp.sin(th)*xp.sin(ph)
    dz = -xp.cos(th)
    v = xp.array([dx, dy, dz], dtype=xp.float32)
    v = v / (xp.linalg.norm(v) + 1e-12)
    return v

# ---------- RELAXED: show far/horizon intersections ----------
def ground_intersection(d, h_km: float, dz_min: float = -1e-6):
    dz = as_float(d[2])
    if dz >= dz_min:
        return None
    t = -h_km / dz
    p = xp.array([0.0, 0.0, h_km], dtype=xp.float32) + t * d
    p[2] = 0.0
    return p
# ------------------------------------------------------------

def footprint_radii_km(h_km: float, az_bw_deg: float, el_bw_deg: float) -> tuple[float,float]:
    ax = __import__("math").tan(__import__("math").radians(max(1e-6, az_bw_deg)*0.5))
    ay = __import__("math").tan(__import__("math").radians(max(1e-6, el_bw_deg)*0.5))
    return h_km*ax, h_km*ay

# ----------------------------
# Directional gain/loss metrics
# ----------------------------

def gain_at_direction_db(spec: ArraySpec, w, theta_deg: float, phi_deg: float) -> float:
    af = array_factor(spec, w, xp.asarray([theta_deg], dtype=xp.float32), phi_deg)
    mag0 = as_float(xp.abs(af)[0])
    return 20.0 * __import__("math").log10(max(mag0, 1e-12))

@dataclass
class DirectionalMetrics:
    beam_theta: float
    beam_phi: float
    gain_taskA_db: float
    gain_taskB_db: float
    directional_loss_db: float

def measure_directional_metrics(spec: ArraySpec, wA, wB,
                                theta_deg: float, phi_deg: float) -> DirectionalMetrics:
    gA = gain_at_direction_db(spec, wA, theta_deg, phi_deg)
    gB = gain_at_direction_db(spec, wB, theta_deg, phi_deg)
    return DirectionalMetrics(theta_deg, phi_deg, gA, gB, gB - gA)

# ----------------------------
# Ground footprint plotting
# ----------------------------

def plot_beam_footprints(beams_rows, spec: ArraySpec, sat: SatSpec,
                         weightsA: list, weightsB: list | None = None,
                         annotate_gain: bool = True, figsize=(8,6)):
    fig, ax = plt.subplots(figsize=figsize)
    centers_xy = []

    for i, r in enumerate(beams_rows):
        th, ph = r["theta"], r["phi"]
        azw, elw = r["az_bw"], r["el_bw"]

        d = beam_direction_vector(th, ph)
        p = ground_intersection(d, sat.h_km)
        if p is None:
            continue
        p_cpu = to_cpu(p)

        rx, ry = footprint_radii_km(sat.h_km, azw, elw)

        # --- NEW: color by activity ratio if Task B weights are provided ---
        edge_color = "C0"
        if weightsB is not None and i < len(weightsB):
            active_ratio = float(xp.count_nonzero(xp.abs(weightsB[i]) > 1e-12)) / (spec.N * spec.N)
            edge_color = "tab:green" if active_ratio >= 0.7 else "tab:red"

        if sat.plane == "xy":
            center = (float(p_cpu[0]), float(p_cpu[1]))
            e = Ellipse(center, 2*rx, 2*ry, angle=ph, fill=False, lw=1.4, edgecolor=edge_color)
            ax.add_patch(e)
            cx, cy = center
            centers_xy.append(center)
        elif sat.plane == "xz":
            center = (float(p_cpu[0]), 0.0)
            r_avg = 0.5*(rx+ry)
            circ = plt.Circle(center, r_avg, fill=False, lw=1.4, edgecolor=edge_color)
            ax.add_artist(circ)
            cx, cy = center
            centers_xy.append((center[0], 0.0))
        elif sat.plane == "yz":
            center = (float(p_cpu[1]), 0.0)
            r_avg = 0.5*(rx+ry)
            circ = plt.Circle(center, r_avg, fill=False, lw=1.4, edgecolor=edge_color)
            ax.add_artist(circ)
            cx, cy = center
            centers_xy.append((center[0], 0.0))
        else:
            raise ValueError("sat.plane must be 'xy', 'xz', or 'yz'")

        if annotate_gain:
            gA = gain_at_direction_db(spec, weightsA[i], th, ph)
            label = f"{i}: θ={th:.1f}°,φ={ph:.1f}°\nA:{gA:.1f} dB"
            if weightsB is not None and i < len(weightsB):
                gB = gain_at_direction_db(spec, weightsB[i], th, ph)
                label += f", B:{gB:.1f} dB, Δ:{(gB-gA):.1f} dB"
            ax.text(cx, cy, label, fontsize=7, ha="center", va="center")

    # Bound axes to content with padding (bigger for far footprints)
    if centers_xy:
        xs, ys = zip(*centers_xy)
        pad = max(50.0, 0.1 * max((max(xs)-min(xs)) + (max(ys)-min(ys)), 1000.0))
        ax.set_xlim(min(xs)-pad, max(xs)+pad)
        ax.set_ylim(min(ys)-pad, max(ys)+pad)

    ax.set_aspect("equal", adjustable="box")
    ax.grid(True, ls=":")
    if sat.plane == "xy":
        ax.set_xlabel("x (km)"); ax.set_ylabel("y (km)")
    elif sat.plane == "xz":
        ax.set_xlabel("x (km)"); ax.set_ylabel("z=0 plane (km)")
    else:
        ax.set_xlabel("y (km)"); ax.set_ylabel("z=0 plane (km)")
    ax.set_title(f"Beam footprints on ground ({sat.plane.upper()} view), h={sat.h_km:.0f} km")
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    return fig, ax

# ----------------------------
# Realtime handover scaffolding (stubs)
# ----------------------------

@dataclass
class EphemerisSample:
    t_ms: int
    sat_pos_km: t.Any
    sat_att_euler_deg: t.Any

class EphemerisProvider:
    def __init__(self): pass
    def get_now(self) -> EphemerisSample:
        return EphemerisSample(0, xp.array([0,0,550.0], dtype=xp.float32), xp.array([0,0,0], dtype=xp.float32))

@dataclass
class UserState:
    t_ms: int
    xy_km: t.Any

class UserTracker:
    def __init__(self): pass
    def get_now(self) -> UserState:
        return UserState(0, xp.array([50.0, 10.0], dtype=xp.float32))

@dataclass
class BeamEntry:
    idx: int
    theta: float
    phi: float
    amp: t.Any
    wA: t.Any
    wB: t.Any | None

class BeamCatalogue:
    def __init__(self):
        self.bank: list[BeamEntry] = []
    def add(self, entry: BeamEntry):
        self.bank.append(entry)
    def nearest(self, theta: float, phi: float) -> BeamEntry:
        return min(self.bank, key=lambda e: (e.theta-theta)**2 + (e.phi-phi)**2)

def user_xy_to_angles(user_xy_km, eph: EphemerisSample) -> tuple[float, float]:
    x = as_float(user_xy_km[0]); y = as_float(user_xy_km[1])
    h = max(1e-3, float(as_float(eph.sat_pos_km[2])))
    r = (x**2 + y**2) ** 0.5
    import math
    theta = math.degrees(math.atan2(r, h))
    phi = math.degrees(math.atan2(y, x))
    return theta, phi

class HandoverController:
    def __init__(self, spec: ArraySpec, cat: BeamCatalogue, use_task: str = "A",
                 hysteresis_db: float = 1.0, ttt_ms: int = 50):
        self.spec = spec
        self.cat = cat
        self.use_task = use_task
        self.hysteresis_db = hysteresis_db
        self.ttt_ms = ttt_ms
        self.current: BeamEntry | None = None
        self._pending: tuple[BeamEntry, int] | None = None

    def _pick_weights(self, entry: BeamEntry):
        if self.use_task == "B" and entry.wB is not None:
            return entry.wB
        return entry.wA

    def _predict_gain_db(self, entry: BeamEntry, theta: float, phi: float) -> float:
        w = self._pick_weights(entry)
        return gain_at_direction_db(self.spec, w, theta, phi)

    def maybe_handover(self, now_ms: int, user: UserState, eph: EphemerisSample):
        th, ph = user_xy_to_angles(user.xy_km, eph)
        cand = self.cat.nearest(th, ph)

        if self.current is None:
            self.current = cand
            return self._pick_weights(self.current), True, self.current

        g_cur = self._predict_gain_db(self.current, th, ph)
        g_cand = self._predict_gain_db(cand, th, ph)
        margin = g_cand - g_cur

        if margin > self.hysteresis_db:
            if self._pending is None or self._pending[0] != cand:
                self._pending = (cand, now_ms)
            if now_ms - self._pending[1] >= self.ttt_ms:
                self.current = cand
                self._pending = None
                return self._pick_weights(self.current), True, self.current
        else:
            self._pending = None

        return self._pick_weights(self.current), False, self.current

# ----------------------------
# Main
# ----------------------------

if __name__ == "__main__":
    print(f"[INFO] Backend: {BACKEND}")
    spec = ArraySpec(N=100, d=0.5)

    # === Load the specification file ===
    rows = []
    with open("/content/Topic 2 Information on the beam position and beam width of multiple beams.csv", "r", newline="") as f:
        reader = csv.DictReader(f)
        for r in reader:
            rows.append({
                "theta": float(r["theta(deg)"]),
                "phi": float(r["phi(deg)"]),
                "az_bw": float(r["Beam Width in azimuth(deg)"]),
                "el_bw": float(r["Beam Width in elevation(deg)"]),
            })

    # === Task A for each row ===
    reports_A = []
    beams_and_amps = []
    for idx, r in enumerate(rows):
        beam = BeamSpec(theta_deg=r["theta"], phi_deg=r["phi"], window="hann")
        amp_target = build_amp_for_target_widths(spec, beam, az_bw_deg=r["az_bw"], el_bw_deg=r["el_bw"])
        wA = design_beam_weights(spec, beam, amp_override=amp_target)
        repA = analyze_beam(spec, wA, cut_phi_deg=beam.phi_deg)
        reports_A.append(repA)
        beams_and_amps.append((beam, amp_target, wA))
        print(f"[Row {idx}] Task A: θ={r['theta']:.2f}°, φ={r['phi']:.2f}° | HPBW_el≈{r['el_bw']:.2f}°, HPBW_az≈{r['az_bw']:.2f}°")

    # === Task B (30% off) diagnostics for each row ===
    for idx, (beam, amp_target, wA) in enumerate(beams_and_amps):
        mask = make_thinning_mask(spec.N, frac_off=0.30, strategy="blue_noise_like", seed=idx)
        w_thin = apply_thinning(wA, mask)
        w_thin = retaper_active_elements(w_thin, mask, amp_target=amp_target, w_phase_ref=wA)

        # visualize mask for the first beam (or any idx you like)
        if idx == 0:
            show_array_mask(mask, title="Task B mask (70% active / 30% off)")
            plt.show()

        gA_dir = gain_at_direction_db(spec, wA, beam.theta_deg, beam.phi_deg)
        gB_dir = gain_at_direction_db(spec, w_thin, beam.theta_deg, beam.phi_deg)
        mainlobe_loss_db = gB_dir - gA_dir

        rep1 = analyze_beam(spec, w_thin, cut_phi_deg=beam.phi_deg)
        hpbw_el = _hpbw_from_cut(spec, w_thin, beam.theta_deg, beam.phi_deg, vary="theta", span_deg=10.0)
        hpbw_az = _hpbw_from_cut(spec, w_thin, beam.theta_deg, beam.phi_deg, vary="phi",   span_deg=10.0)
        print(f"[Row {idx}] Task B: ΔMain-lobe={mainlobe_loss_db:.2f} dB, "
              f"HPBW_elev≈{hpbw_el:.2f}°, HPBW_az≈{hpbw_az:.2f}°, SLL={rep1.peak_sll_db:.1f} dB")

    # === Directional gain/loss + footprint plot ===
    taskB_weights = []
    directional_table = []
    # --- XY top-down view (this is the 'where to put' change) ---
    sat = SatSpec(h_km=50.0, plane="xy")

    for idx, (beam, amp_target, wA) in enumerate(beams_and_amps):
        mask = make_thinning_mask(spec.N, frac_off=0.30, strategy="blue_noise_like", seed=idx)
        wB = retaper_active_elements(apply_thinning(wA, mask), mask, amp_target, w_phase_ref=wA)
        taskB_weights.append(wB)

        dm = measure_directional_metrics(spec, wA, wB, beam.theta_deg, beam.phi_deg)
        directional_table.append(dm)

    print("\nDirectional Gain Comparison (Task A vs Task B)")
    print("Idx | θ φ | GainA | GainB | Δ(B-A)")
    # --- print ALL rows  ---
    for i, dm in enumerate(directional_table):
        print(f"{i:3d} | {dm.beam_theta:5.1f} {dm.beam_phi:5.1f} | "
              f"{dm.gain_taskA_db:6.2f} | {dm.gain_taskB_db:6.2f} | {dm.directional_loss_db:6.2f}")

    # Plot first 20 beam footprints (colored by active ratio when B is provided)
    subset = rows[:20]
    wA_subset = [beams_and_amps[i][2] for i in range(min(20, len(beams_and_amps)))]
    wB_subset = taskB_weights[:len(wA_subset)]
    plot_beam_footprints(subset[:len(wA_subset)], spec, sat, wA_subset, wB_subset, annotate_gain=True)
    plt.show()

    # --- Build catalogue from actual Task A/B beams ---
    cat = BeamCatalogue()
    for idx, ((beam, amp_target, wA), wB) in enumerate(zip(beams_and_amps, taskB_weights)):
        cat.add(BeamEntry(idx=idx, theta=beam.theta_deg, phi=beam.phi_deg, amp=amp_target, wA=wA, wB=wB))

    # --- Handover controller ---
    ephprov = EphemerisProvider()
    usertrk  = UserTracker()
    ctrl = HandoverController(spec, cat, use_task="B", hysteresis_db=0.7, ttt_ms=40)

    # Longer simulation: 40 steps (2s at 50 ms), faster user motion to encourage switches
    print("\nHandover simulation:")
    for step in range(0, 40):
        now_ms = step * 50
        eph = ephprov.get_now()
        user = usertrk.get_now()
        user.xy_km = xp.array([50.0 + 20.0*step, 10.0], dtype=xp.float32)  # faster sweep

        w_active, switched, active_entry = ctrl.maybe_handover(now_ms, user, eph)
        th, ph = user_xy_to_angles(user.xy_km, eph)
        g_act = gain_at_direction_db(spec, w_active, th, ph)
        print(f"[{now_ms:4d} ms] active beam idx={active_entry.idx} "
              f"(θ={active_entry.theta:.1f}°, φ={active_entry.phi:.1f}°), "
              f"gain={g_act:.1f} dB, switched={switched}")

    # Physics note:
    # With ||w||_F = 1, turning off 30% implies ~10*log10(0.7) ≈ -1.55 dB power loss for fully coherent beams.
# Out:
# [INFO] Backend: cupy
# [Row 0] Task A: θ=90.00°, φ=90.00° | HPBW_el≈5.94°, HPBW_az≈5.94°
# [Row 1] Task A: θ=92.54°, φ=86.33° | HPBW_el≈6.22°, HPBW_az≈4.86°
# [Row 2] Task A: θ=87.46°, φ=93.67° | HPBW_el≈6.25°, HPBW_az≈4.86°
# [Row 3] Task A: θ=92.80°, φ=93.64° | HPBW_el≈6.22°, HPBW_az≈4.86°
# [Row 4] Task A: θ=87.33°, φ=86.19° | HPBW_el≈6.14°, HPBW_az≈5.47°
# [Row 5] Task A: θ=84.78°, φ=89.85° | HPBW_el≈6.14°, HPBW_az≈5.49°
# [Row 6] Task A: θ=95.33°, φ=89.96° | HPBW_el≈6.20°, HPBW_az≈4.85°
# [Row 7] Task A: θ=90.26°, φ=97.28° | HPBW_el≈6.21°, HPBW_az≈4.82°
# [Row 8] Task A: θ=89.88°, φ=82.56° | HPBW_el≈6.11°, HPBW_az≈5.38°
# [Row 9] Task A: θ=82.28°, φ=93.51° | HPBW_el≈6.13°, HPBW_az≈5.46°
# [Row 10] Task A: θ=97.81°, φ=86.29° | HPBW_el≈6.13°, HPBW_az≈4.82°
# [Row 11] Task A: θ=82.88°, φ=85.01° | HPBW_el≈5.71°, HPBW_az≈5.98°
# [Row 12] Task A: θ=98.06°, φ=93.59° | HPBW_el≈6.09°, HPBW_az≈4.82°
# [Row 13] Task A: θ=95.03°, φ=82.70° | HPBW_el≈6.15°, HPBW_az≈4.79°
# [Row 14] Task A: θ=84.97°, φ=97.30° | HPBW_el≈6.21°, HPBW_az≈4.80°
# [Row 15] Task A: θ=95.54°, φ=97.24° | HPBW_el≈6.12°, HPBW_az≈4.80°
# [Row 16] Task A: θ=85.44°, φ=81.40° | HPBW_el≈5.70°, HPBW_az≈5.90°
# [Row 17] Task A: θ=80.35°, φ=88.65° | HPBW_el≈5.70°, HPBW_az≈5.99°
# [Row 18] Task A: θ=100.53°, φ=89.92° | HPBW_el≈6.03°, HPBW_az≈4.79°
# [Row 19] Task A: θ=87.77°, φ=100.85° | HPBW_el≈6.17°, HPBW_az≈4.73°
# [Row 20] Task A: θ=93.02°, φ=100.82° | HPBW_el≈6.11°, HPBW_az≈4.73°
# [Row 21] Task A: θ=92.38°, φ=79.00° | HPBW_el≈6.06°, HPBW_az≈5.25°
# [Row 22] Task A: θ=87.98°, φ=77.87° | HPBW_el≈5.68°, HPBW_az≈5.76°
# [Row 23] Task A: θ=77.90°, φ=92.31° | HPBW_el≈5.68°, HPBW_az≈5.94°
# [Row 24] Task A: θ=79.86°, φ=97.13° | HPBW_el≈6.10°, HPBW_az≈5.37°
# [Row 25] Task A: θ=100.20°, φ=82.66° | HPBW_el≈6.02°, HPBW_az≈4.73°
# [Row 26] Task A: θ=100.70°, φ=97.19° | HPBW_el≈5.91°, HPBW_az≈4.73°
# [Row 27] Task A: θ=78.66°, φ=83.66° | HPBW_el≈5.49°, HPBW_az≈5.87°
# [Row 28] Task A: θ=97.44°, φ=79.14° | HPBW_el≈6.04°, HPBW_az≈4.67°
# [Row 29] Task A: θ=82.56°, φ=100.86° | HPBW_el≈6.14°, HPBW_az≈4.69°
# [Row 30] Task A: θ=81.21°, φ=80.09° | HPBW_el≈5.49°, HPBW_az≈5.80°
# [Row 31] Task A: θ=102.92°, φ=86.25° | HPBW_el≈5.93°, HPBW_az≈4.73°
# [Row 32] Task A: θ=98.18°, φ=100.78° | HPBW_el≈5.94°, HPBW_az≈4.68°
# [Row 33] Task A: θ=103.16°, φ=93.54° | HPBW_el≈5.85°, HPBW_az≈4.73°
# [Row 34] Task A: θ=76.17°, φ=87.29° | HPBW_el≈5.47°, HPBW_az≈5.89°
# [Row 35] Task A: θ=90.53°, φ=104.31° | HPBW_el≈6.07°, HPBW_az≈4.61°
# [Row 36] Task A: θ=83.78°, φ=76.60° | HPBW_el≈5.49°, HPBW_az≈5.67°
# [Row 37] Task A: θ=85.36°, φ=104.33° | HPBW_el≈6.09°, HPBW_az≈4.59°
# [Row 38] Task A: θ=94.80°, φ=75.54° | HPBW_el≈5.99°, HPBW_az≈5.07°
# [Row 39] Task A: θ=95.67°, φ=104.27° | HPBW_el≈5.93°, HPBW_az≈4.58°
# [Row 40] Task A: θ=105.53°, φ=89.86° | HPBW_el≈5.77°, HPBW_az≈4.69°
# [Row 41] Task A: θ=90.48°, φ=74.45° | HPBW_el≈5.65°, HPBW_az≈5.57°
# [Row 42] Task A: θ=75.56°, φ=95.93° | HPBW_el≈5.65°, HPBW_az≈5.83°
# [Row 43] Task A: θ=73.78°, φ=90.93° | HPBW_el≈5.45°, HPBW_az≈5.84°
# [Row 44] Task A: θ=77.57°, φ=100.68° | HPBW_el≈6.05°, HPBW_az≈5.23°
# [Row 45] Task A: θ=102.48°, φ=79.10° | HPBW_el≈5.89°, HPBW_az≈4.59°
# [Row 46] Task A: θ=105.18°, φ=82.62° | HPBW_el≈5.80°, HPBW_az≈4.63°
# [Row 47] Task A: θ=103.19°, φ=100.71° | HPBW_el≈5.77°, HPBW_az≈4.60°
# [Row 48] Task A: θ=77.13°, φ=78.79° | HPBW_el≈5.20°, HPBW_az≈5.66°
# [Row 49] Task A: θ=74.61°, φ=82.33° | HPBW_el≈5.19°, HPBW_az≈5.73°
# [Row 50] Task A: θ=105.65°, φ=97.12° | HPBW_el≈5.69°, HPBW_az≈4.63°
# [Row 51] Task A: θ=86.32°, φ=73.22° | HPBW_el≈5.47°, HPBW_az≈5.48°
# [Row 52] Task A: θ=99.74°, φ=75.67° | HPBW_el≈5.91°, HPBW_az≈4.51°
# [Row 53] Task A: θ=80.27°, φ=104.33° | HPBW_el≈6.04°, HPBW_az≈4.54°
# [Row 54] Task A: θ=100.69°, φ=104.22° | HPBW_el≈5.79°, HPBW_az≈4.52°
# [Row 55] Task A: θ=88.12°, φ=107.68° | HPBW_el≈5.99°, HPBW_az≈4.45°
# [Row 56] Task A: θ=79.70°, φ=75.34° | HPBW_el≈5.21°, HPBW_az≈5.53°
# [Row 57] Task A: θ=93.19°, φ=107.65° | HPBW_el≈5.90°, HPBW_az≈4.44°
# [Row 58] Task A: θ=107.78°, φ=86.19° | HPBW_el≈5.64°, HPBW_az≈4.61°
# [Row 59] Task A: θ=72.18°, φ=85.93° | HPBW_el≈5.17°, HPBW_az≈5.74°
# [Row 60] Task A: θ=108.01°, φ=93.47° | HPBW_el≈5.55°, HPBW_az≈4.61°
# [Row 61] Task A: θ=83.07°, φ=107.69° | HPBW_el≈5.98°, HPBW_az≈4.42°
# [Row 62] Task A: θ=71.53°, φ=94.56° | HPBW_el≈5.42°, HPBW_az≈5.74°
# [Row 63] Task A: θ=92.88°, φ=71.15° | HPBW_el≈5.60°, HPBW_az≈5.34°
# [Row 64] Task A: θ=73.36°, φ=99.50° | HPBW_el≈5.61°, HPBW_az≈5.67°
# [Row 65] Task A: θ=97.11°, φ=72.20° | HPBW_el≈5.91°, HPBW_az≈4.86°
# [Row 66] Task A: θ=98.19°, φ=107.61° | HPBW_el≈5.74°, HPBW_az≈4.40°
# [Row 67] Task A: θ=82.26°, φ=72.01° | HPBW_el≈5.21°, HPBW_az≈5.36°
# [Row 68] Task A: θ=88.79°, φ=69.97° | HPBW_el≈5.43°, HPBW_az≈5.26°
# [Row 69] Task A: θ=69.86°, φ=89.56° | HPBW_el≈5.14°, HPBW_az≈5.70°
# [Row 70] Task A: θ=75.42°, φ=104.14° | HPBW_el≈5.98°, HPBW_az≈5.05°
# [Row 71] Task A: θ=110.26°, φ=89.79° | HPBW_el≈5.43°, HPBW_az≈4.55°
# [Row 72] Task A: θ=107.28°, φ=79.06° | HPBW_el≈5.65°, HPBW_az≈4.49°
# [Row 73] Task A: θ=104.60°, φ=75.64° | HPBW_el≈5.74°, HPBW_az≈4.42°
# [Row 74] Task A: θ=73.24°, φ=77.52° | HPBW_el≈4.86°, HPBW_az≈5.48°
# [Row 75] Task A: θ=107.97°, φ=100.63° | HPBW_el≈5.55°, HPBW_az≈4.49°
# [Row 76] Task A: θ=105.52°, φ=104.14° | HPBW_el≈5.63°, HPBW_az≈4.43°
# [Row 77] Task A: θ=90.78°, φ=110.89° | HPBW_el≈5.83°, HPBW_az≈4.27°
# [Row 78] Task A: θ=70.77°, φ=81.02° | HPBW_el≈4.83°, HPBW_az≈5.56°
# [Row 79] Task A: θ=109.88°, φ=82.57° | HPBW_el≈5.50°, HPBW_az≈4.50°
# [Row 80] Task A: θ=101.88°, φ=72.33° | HPBW_el≈5.76°, HPBW_az≈4.32°
# [Row 81] Task A: θ=78.12°, φ=107.67° | HPBW_el≈5.92°, HPBW_az≈4.35°
# [Row 82] Task A: θ=75.78°, φ=74.12° | HPBW_el≈4.88°, HPBW_az≈5.36°
# [Row 83] Task A: θ=85.82°, φ=110.91° | HPBW_el≈5.89°, HPBW_az≈4.26°
# [Row 84] Task A: θ=110.33°, φ=97.04° | HPBW_el≈5.41°, HPBW_az≈4.50°
# [Row 85] Task A: θ=95.72°, φ=110.86° | HPBW_el≈5.68°, HPBW_az≈4.24°
# [Row 86] Task A: θ=103.03°, φ=107.54° | HPBW_el≈5.64°, HPBW_az≈4.33°
# [Row 87] Task A: θ=84.78°, φ=68.82° | HPBW_el≈5.20°, HPBW_az≈5.14°
# [Row 88] Task A: θ=69.43°, φ=98.13° | HPBW_el≈5.38°, HPBW_az≈5.58°
# [Row 89] Task A: θ=68.40°, φ=84.59° | HPBW_el≈4.81°, HPBW_az≈5.57°
# [Row 90] Task A: θ=78.35°, φ=70.84° | HPBW_el≈4.89°, HPBW_az≈5.20°
# [Row 91] Task A: θ=67.69°, φ=93.18° | HPBW_el≈5.12°, HPBW_az≈5.61°
# [Row 92] Task A: θ=95.16°, φ=68.00° | HPBW_el≈5.53°, HPBW_az≈5.09°
# [Row 93] Task A: θ=71.33°, φ=102.98° | HPBW_el≈5.56°, HPBW_az≈5.47°
# [Row 94] Task A: θ=112.35°, φ=86.13° | HPBW_el≈5.30°, HPBW_az≈4.47°
# [Row 95] Task A: θ=80.91°, φ=110.90° | HPBW_el≈5.85°, HPBW_az≈4.21°
# [Row 96] Task A: θ=112.57°, φ=93.39° | HPBW_el≈5.22°, HPBW_az≈4.47°
# [Row 97] Task A: θ=99.27°, φ=69.00° | HPBW_el≈5.80°, HPBW_az≈4.62°
# [Row 98] Task A: θ=91.16°, φ=66.87° | HPBW_el≈5.39°, HPBW_az≈5.01°
# [Row 99] Task A: θ=100.54°, φ=110.80° | HPBW_el≈5.60°, HPBW_az≈4.19°
# [Row 100] Task A: θ=109.22°, φ=75.61° | HPBW_el≈5.49°, HPBW_az≈4.31°
# [Row 101] Task A: θ=73.44°, φ=107.47° | HPBW_el≈5.90°, HPBW_az≈4.84°
# [Row 102] Task A: θ=66.16°, φ=88.20° | HPBW_el≈4.79°, HPBW_az≈5.54°
# [Row 103] Task A: θ=80.89°, φ=67.70° | HPBW_el≈4.90°, HPBW_az≈5.00°
# [Row 104] Task A: θ=88.48°, φ=113.98° | HPBW_el≈5.74°, HPBW_az≈4.06°
# [Row 105] Task A: θ=106.56°, φ=72.31° | HPBW_el≈5.57°, HPBW_az≈4.23°
# [Row 106] Task A: θ=93.32°, φ=113.95° | HPBW_el≈5.62°, HPBW_az≈4.06°
# [Row 107] Task A: θ=111.80°, φ=79.02° | HPBW_el≈5.35°, HPBW_az≈4.35°
# [Row 108] Task A: θ=110.10°, φ=104.05° | HPBW_el≈5.39°, HPBW_az≈4.31°
# [Row 109] Task A: θ=87.22°, φ=65.78° | HPBW_el≈5.17°, HPBW_az≈4.90°
# [Row 110] Task A: θ=69.57°, φ=76.28° | HPBW_el≈4.47°, HPBW_az≈5.29°
# [Row 111] Task A: θ=72.07°, φ=72.93° | HPBW_el≈4.50°, HPBW_az≈5.17°
# [Row 112] Task A: θ=107.67°, φ=107.45° | HPBW_el≈5.47°, HPBW_az≈4.23°
# [Row 113] Task A: θ=114.66°, φ=89.72° | HPBW_el≈5.04°, HPBW_az≈4.40°
# [Row 114] Task A: θ=112.45°, φ=100.54° | HPBW_el≈5.26°, HPBW_az≈4.35°
# [Row 115] Task A: θ=83.65°, φ=113.98° | HPBW_el≈5.77°, HPBW_az≈4.04°
# [Row 116] Task A: θ=103.87°, φ=69.13° | HPBW_el≈5.59°, HPBW_az≈4.10°
# [Row 117] Task A: θ=76.13°, φ=110.87° | HPBW_el≈5.78°, HPBW_az≈4.14°
# [Row 118] Task A: θ=67.15°, φ=79.74° | HPBW_el≈4.44°, HPBW_az≈5.36°
# [Row 119] Task A: θ=98.09°, φ=113.91° | HPBW_el≈5.54°, HPBW_az≈4.02°
# [Row 120] Task A: θ=65.70°, φ=96.76° | HPBW_el≈5.09°, HPBW_az≈5.46°
# [Row 121] Task A: θ=67.51°, φ=101.63° | HPBW_el≈5.33°, HPBW_az≈5.39°
# [Row 122] Task A: θ=74.62°, φ=69.70° | HPBW_el≈4.53°, HPBW_az≈5.02°
# [Row 123] Task A: θ=114.27°, φ=82.51° | HPBW_el≈5.15°, HPBW_az≈4.35°
# [Row 124] Task A: θ=105.20°, φ=110.72° | HPBW_el≈5.48°, HPBW_az≈4.11°
# [Row 125] Task A: θ=114.69°, φ=96.94° | HPBW_el≈5.08°, HPBW_az≈4.35°
# [Row 126] Task A: θ=64.09°, φ=91.81° | HPBW_el≈4.77°, HPBW_az≈5.45°
# [Row 127] Task A: θ=64.86°, φ=83.27° | HPBW_el≈4.42°, HPBW_az≈5.38°
# [Row 128] Task A: θ=97.31°, φ=65.00° | HPBW_el≈5.45°, HPBW_az≈4.81°
# [Row 129] Task A: θ=69.48°, φ=106.34° | HPBW_el≈5.50°, HPBW_az≈5.23°
# [Row 130] Task A: θ=83.38°, φ=64.71° | HPBW_el≈4.89°, HPBW_az≈4.77°
# [Row 131] Task A: θ=78.90°, φ=113.96° | HPBW_el≈5.71°, HPBW_az≈3.99°
# [Row 132] Task A: θ=93.42°, φ=63.93° | HPBW_el≈5.32°, HPBW_az≈4.74°
# [Row 133] Task A: θ=101.29°, φ=65.96° | HPBW_el≈5.69°, HPBW_az≈4.36°
# [Row 134] Task A: θ=77.17°, φ=66.62° | HPBW_el≈4.55°, HPBW_az≈4.83°
# [Row 135] Task A: θ=102.73°, φ=113.84° | HPBW_el≈5.44°, HPBW_az≈3.97°
# [Row 136] Task A: θ=116.58°, φ=86.06° | HPBW_el≈4.91°, HPBW_az≈4.31°
# [Row 137] Task A: θ=91.01°, φ=116.89° | HPBW_el≈5.54°, HPBW_az≈3.85°
# [Row 138] Task A: θ=116.79°, φ=93.29° | HPBW_el≈4.85°, HPBW_az≈4.31°
# [Row 139] Task A: θ=89.57°, φ=62.89° | HPBW_el≈5.13°, HPBW_az≈4.64°
# [Row 140] Task A: θ=86.30°, φ=116.90° | HPBW_el≈5.63°, HPBW_az≈3.85°
# [Row 141] Task A: θ=110.98°, φ=72.28° | HPBW_el≈5.32°, HPBW_az≈4.11°
# [Row 142] Task A: θ=71.63°, φ=110.66° | HPBW_el≈5.81°, HPBW_az≈4.60°
# [Row 143] Task A: θ=113.54°, φ=75.58° | HPBW_el≈5.18°, HPBW_az≈4.18°
# [Row 144] Task A: θ=95.70°, φ=116.85° | HPBW_el≈5.43°, HPBW_az≈3.83°
# [Row 145] Task A: θ=62.71°, φ=86.85° | HPBW_el≈4.40°, HPBW_az≈5.35°
# [Row 146] Task A: θ=108.35°, φ=69.12° | HPBW_el≈5.39°, HPBW_az≈4.01°
# [Row 147] Task A: θ=112.03°, φ=107.34° | HPBW_el≈5.22°, HPBW_az≈4.11°
# [Row 148] Task A: θ=68.59°, φ=71.76° | HPBW_el≈4.10°, HPBW_az≈4.96°
# [Row 149] Task A: θ=114.38°, φ=103.94° | HPBW_el≈5.10°, HPBW_az≈4.18°
# [Row 150] Task A: θ=66.14°, φ=75.06° | HPBW_el≈4.07°, HPBW_az≈5.07°
# [Row 151] Task A: θ=63.90°, φ=100.28° | HPBW_el≈5.05°, HPBW_az≈5.28°
# [Row 152] Task A: θ=81.62°, φ=116.89° | HPBW_el≈5.63°, HPBW_az≈3.82°
# [Row 153] Task A: θ=116.00°, φ=78.97° | HPBW_el≈5.00°, HPBW_az≈4.20°
# [Row 154] Task A: θ=79.69°, φ=63.69° | HPBW_el≈4.57°, HPBW_az≈4.61°
# [Row 155] Task A: θ=109.62°, φ=110.62° | HPBW_el≈5.29°, HPBW_az≈4.02°
# [Row 156] Task A: θ=65.78°, φ=105.02° | HPBW_el≈5.28°, HPBW_az≈5.17°
# [Row 157] Task A: θ=71.10°, φ=68.59° | HPBW_el≈4.13°, HPBW_az≈4.84°
# [Row 158] Task A: θ=62.20°, φ=95.39° | HPBW_el≈4.75°, HPBW_az≈5.32°
# [Row 159] Task A: θ=105.70°, φ=66.09° | HPBW_el≈5.41°, HPBW_az≈3.88°
# [Row 160] Task A: θ=74.31°, φ=113.91° | HPBW_el≈5.63°, HPBW_az≈3.92°
# [Row 161] Task A: θ=85.80°, φ=61.89° | HPBW_el≈4.87°, HPBW_az≈4.52°
# [Row 162] Task A: θ=116.62°, φ=100.42° | HPBW_el≈4.93°, HPBW_az≈4.20°
# [Row 163] Task A: θ=63.79°, φ=78.47° | HPBW_el≈4.04°, HPBW_az≈5.14°
# [Row 164] Task A: θ=100.29°, φ=116.79° | HPBW_el≈5.38°, HPBW_az≈3.79°
# [Row 165] Task A: θ=118.72°, φ=89.63° | HPBW_el≈4.63°, HPBW_az≈4.23°
# [Row 166] Task A: θ=107.17°, φ=113.74° | HPBW_el≈5.31°, HPBW_az≈3.89°
# [Row 167] Task A: θ=73.63°, φ=65.57° | HPBW_el≈4.15°, HPBW_az≈4.68°
# [Row 168] Task A: θ=99.30°, φ=62.17° | HPBW_el≈5.35°, HPBW_az≈4.52°
# [Row 169] Task A: θ=118.32°, φ=82.45° | HPBW_el≈4.77°, HPBW_az≈4.19°
# [Row 170] Task A: θ=67.81°, φ=109.56° | HPBW_el≈5.42°, HPBW_az≈4.98°
# [Row 171] Task A: θ=60.73°, φ=90.45° | HPBW_el≈4.39°, HPBW_az≈5.27°
# [Row 172] Task A: θ=95.53°, φ=61.16° | HPBW_el≈5.24°, HPBW_az≈4.45°
# [Row 173] Task A: θ=61.57°, φ=81.97° | HPBW_el≈4.02°, HPBW_az≈5.16°
# [Row 174] Task A: θ=118.72°, φ=96.83° | HPBW_el≈4.72°, HPBW_az≈4.18°
# [Row 175] Task A: θ=77.06°, φ=116.85° | HPBW_el≈5.57°, HPBW_az≈3.77°
# [Row 176] Task A: θ=103.14°, φ=63.08° | HPBW_el≈5.56°, HPBW_az≈4.10°
# [Row 177] Task A: θ=93.41°, φ=119.63° | HPBW_el≈5.31°, HPBW_az≈3.63°
# [Row 178] Task A: θ=91.78°, φ=60.18° | HPBW_el≈5.07°, HPBW_az≈4.37°
# [Row 179] Task A: θ=82.14°, φ=60.92° | HPBW_el≈4.58°, HPBW_az≈4.37°
# [Row 180] Task A: θ=104.72°, φ=116.71° | HPBW_el≈5.27°, HPBW_az≈3.73°
# [Row 181] Task A: θ=76.15°, φ=62.70° | HPBW_el≈4.18°, HPBW_az≈4.47°
# [Row 182] Task A: θ=112.56°, φ=69.11° | HPBW_el≈5.13°, HPBW_az≈3.90°
# [Row 183] Task A: θ=115.10°, φ=72.26° | HPBW_el≈5.01°, HPBW_az≈3.98°
# [Row 184] Task A: θ=97.92°, φ=119.58° | HPBW_el≈5.28°, HPBW_az≈3.60°
# [Row 185] Task A: θ=70.00°, φ=113.70° | HPBW_el≈5.70°, HPBW_az≈4.36°
# [Row 186] Task A: θ=120.47°, φ=85.98° | HPBW_el≈4.51°, HPBW_az≈4.14°
# [Row 187] Task A: θ=109.97°, φ=66.09° | HPBW_el≈5.21°, HPBW_az≈3.78°
# [Row 188] Task A: θ=59.51°, φ=85.52° | HPBW_el≈4.01°, HPBW_az≈5.14°
# [Row 189] Task A: θ=120.67°, φ=93.19° | HPBW_el≈4.47°, HPBW_az≈4.13°
# [Row 190] Task A: θ=88.10°, φ=59.23° | HPBW_el≈4.84°, HPBW_az≈4.26°
# [Row 191] Task A: θ=117.55°, φ=75.54° | HPBW_el≈4.84°, HPBW_az≈4.03°
# [Row 192] Task A: θ=116.10°, φ=107.21° | HPBW_el≈4.94°, HPBW_az≈3.98°
# [Row 193] Task A: θ=65.34°, φ=70.64° | HPBW_el≈3.88°, HPBW_az≈4.80°
# [Row 194] Task A: θ=113.77°, φ=110.49° | HPBW_el≈5.05°, HPBW_az≈3.90°
# [Row 195] Task A: θ=62.95°, φ=73.88° | HPBW_el≈3.78°, HPBW_az≈4.86°
# [Row 196] Task A: θ=67.80°, φ=67.52° | HPBW_el≈3.95°, HPBW_az≈4.69°
# [Row 197] Task A: θ=64.23°, φ=108.28° | HPBW_el≈5.22°, HPBW_az≈4.92°
# [Row 198] Task A: θ=118.34°, φ=103.80° | HPBW_el≈4.78°, HPBW_az≈4.03°
# [Row 199] Task A: θ=58.94°, φ=94.02° | HPBW_el≈4.39°, HPBW_az≈5.15°
# [Row 200] Task A: θ=111.37°, φ=113.63° | HPBW_el≈5.12°, HPBW_az≈3.79°
# [Row 201] Task A: θ=107.35°, φ=63.22° | HPBW_el≈5.23°, HPBW_az≈3.64°
# [Row 202] Task A: θ=72.65°, φ=116.79° | HPBW_el≈5.46°, HPBW_az≈3.69°
# [Row 203] Task A: θ=119.86°, φ=78.93° | HPBW_el≈4.63°, HPBW_az≈4.04°
# [Row 204] Task A: θ=60.67°, φ=77.24° | HPBW_el≈3.65°, HPBW_az≈4.89°
# [Row 205] Task A: θ=102.31°, φ=119.51° | HPBW_el≈5.21°, HPBW_az≈3.56°
# [Row 206] Task A: θ=70.30°, φ=64.55° | HPBW_el≈3.99°, HPBW_az≈4.54°
# [Row 207] Task A: θ=78.64°, φ=59.99° | HPBW_el≈4.22°, HPBW_az≈4.24°
# [Row 208] Task A: θ=120.45°, φ=100.29° | HPBW_el≈4.58°, HPBW_az≈4.04°
# [Row 209] Task A: θ=84.51°, φ=58.32° | HPBW_el≈4.57°, HPBW_az≈4.13°
# [Row 210] Task A: θ=97.50°, φ=58.55° | HPBW_el≈5.15°, HPBW_az≈4.17°
# [Row 211] Task A: θ=108.95°, φ=116.60° | HPBW_el≈5.13°, HPBW_az≈3.65°
# [Row 212] Task A: θ=101.14°, φ=59.51° | HPBW_el≈5.24°, HPBW_az≈4.23°
# [Row 213] Task A: θ=66.31°, φ=112.63° | HPBW_el≈5.34°, HPBW_az≈4.71°
# [Row 214] Task A: θ=57.62°, φ=89.10° | HPBW_el≈4.01°, HPBW_az≈5.08°
# [Row 215] Task A: θ=122.43°, φ=89.53° | HPBW_el≈4.23°, HPBW_az≈4.05°
# [Row 216] Task A: θ=93.87°, φ=57.63° | HPBW_el≈4.99°, HPBW_az≈4.09°
# [Row 217] Task A: θ=58.54°, φ=80.70° | HPBW_el≈3.61°, HPBW_az≈4.94°
# [Row 218] Task A: θ=75.37°, φ=119.57° | HPBW_el≈5.41°, HPBW_az≈3.53°
# [Row 219] Task A: θ=72.81°, φ=61.74° | HPBW_el≈3.99°, HPBW_az≈4.35°
# [Row 220] Task A: θ=122.02°, φ=82.39° | HPBW_el≈4.38°, HPBW_az≈4.02°
# [Row 221] Task A: θ=122.41°, φ=96.70° | HPBW_el≈4.34°, HPBW_az≈4.01°
# [Row 222] Task A: θ=113.97°, φ=66.09° | HPBW_el≈4.95°, HPBW_az≈3.68°
# [Row 223] Task A: θ=106.54°, φ=119.42° | HPBW_el≈5.10°, HPBW_az≈3.49°
# [Row 224] Task A: θ=81.05°, φ=57.44° | HPBW_el≈4.25°, HPBW_az≈4.00°
# [Row 225] Task A: θ=68.53°, φ=116.57° | HPBW_el≈5.58°, HPBW_az≈4.11°
# [Row 226] Task A: θ=111.42°, φ=63.22° | HPBW_el≈5.02°, HPBW_az≈3.56°
# [Row 227] Task A: θ=117.63°, φ=110.35° | HPBW_el≈4.78°, HPBW_az≈3.78°
# [Row 228] Task A: θ=56.56°, φ=84.21° | HPBW_el≈3.61°, HPBW_az≈4.92°
# [Row 229] Task A: θ=75.30°, φ=59.09° | HPBW_el≈3.96°, HPBW_az≈4.14°
# [Row 230] Task A: θ=62.33°, φ=69.54° | HPBW_el≈3.68°, HPBW_az≈4.65°
# [Row 231] Task A: θ=64.73°, φ=66.49° | HPBW_el≈3.76°, HPBW_az≈4.55°
# [Row 232] Task A: θ=115.31°, φ=113.49° | HPBW_el≈4.88°, HPBW_az≈3.68°
# [Row 233] Task A: θ=119.86°, φ=107.06° | HPBW_el≈4.63°, HPBW_az≈3.84°
# [Row 234] Task A: θ=60.01°, φ=72.73° | HPBW_el≈3.56°, HPBW_az≈4.70°
# [Row 235] Task A: θ=124.01°, φ=85.90° | HPBW_el≈4.12°, HPBW_az≈3.96°
# [Row 236] Task A: θ=86.77°, φ=55.88° | HPBW_el≈4.54°, HPBW_az≈3.88°
# [Row 237] Task A: θ=124.20°, φ=93.07° | HPBW_el≈4.08°, HPBW_az≈3.96°
# [Row 238] Task A: θ=67.19°, φ=63.58° | HPBW_el≈3.82°, HPBW_az≈4.41°
# [Row 239] Task A: θ=112.94°, φ=116.47° | HPBW_el≈4.94°, HPBW_az≈3.56°
# [Row 240] Task A: θ=121.98°, φ=103.66° | HPBW_el≈4.44°, HPBW_az≈3.87°
# [Row 241] Task A: θ=71.16°, φ=119.49° | HPBW_el≈5.30°, HPBW_az≈3.46°
# [Row 242] Task A: θ=57.81°, φ=76.04° | HPBW_el≈3.42°, HPBW_az≈4.70°
# [Row 243] Task A: θ=123.39°, φ=78.88° | HPBW_el≈4.26°, HPBW_az≈3.88°
# [Row 244] Task A: θ=69.67°, φ=60.82° | HPBW_el≈3.84°, HPBW_az≈4.23°
# [Row 245] Task A: θ=77.73°, φ=56.60° | HPBW_el≈3.90°, HPBW_az≈3.91°
# [Row 246] Task A: θ=83.37°, φ=55.05° | HPBW_el≈4.26°, HPBW_az≈3.75°
# [Row 247] Task A: θ=55.75°, φ=79.45° | HPBW_el≈3.26°, HPBW_az≈4.66°
# [Row 248] Task A: θ=125.80°, φ=89.43° | HPBW_el≈3.84°, HPBW_az≈3.87°
# [Row 249] Task A: θ=125.40°, φ=82.32° | HPBW_el≈4.01°, HPBW_az≈3.84°
# [Row 250] Task A: θ=80.09°, φ=54.26° | HPBW_el≈3.90°, HPBW_az≈3.67°
# [Row 251] Task A: θ=74.58°, φ=55.79° | HPBW_el≈3.79°, HPBW_az≈3.81°
# [Row 252] Task A: θ=127.22°, φ=85.81° | HPBW_el≈3.74°, HPBW_az≈3.78°
# [Row 253] Task A: θ=127.40°, φ=92.94° | HPBW_el≈3.71°, HPBW_az≈3.78°
# [Row 254] Task A: θ=76.96°, φ=53.51° | HPBW_el≈3.73°, HPBW_az≈3.58°
# [Row 255] Task A: θ=128.86°, φ=89.31° | HPBW_el≈3.47°, HPBW_az≈3.70°
# [Row 0] Task B: ΔMain-lobe=-1.55 dB, HPBW_elev≈15.80°, HPBW_az≈1.05°, SLL=-0.0 dB
# [Row 1] Task B: ΔMain-lobe=-1.40 dB, HPBW_elev≈12.48°, HPBW_az≈1.03°, SLL=-0.6 dB
# [Row 2] Task B: ΔMain-lobe=-0.44 dB, HPBW_elev≈20.00°, HPBW_az≈1.07°, SLL=-0.9 dB
# [Row 3] Task B: ΔMain-lobe=10.28 dB, HPBW_elev≈16.05°, HPBW_az≈1.05°, SLL=-0.6 dB
# [Row 4] Task B: ΔMain-lobe=6.81 dB, HPBW_elev≈14.45°, HPBW_az≈1.05°, SLL=-0.4 dB
# [Row 5] Task B: ΔMain-lobe=-2.66 dB, HPBW_elev≈11.08°, HPBW_az≈1.03°, SLL=-1.1 dB
# [Row 6] Task B: ΔMain-lobe=-2.41 dB, HPBW_elev≈10.95°, HPBW_az≈1.05°, SLL=-0.0 dB
# [Row 7] Task B: ΔMain-lobe=3.36 dB, HPBW_elev≈20.00°, HPBW_az≈3.88°, SLL=-2.1 dB
# [Row 8] Task B: ΔMain-lobe=16.78 dB, HPBW_elev≈20.00°, HPBW_az≈7.20°, SLL=-1.1 dB
# [Row 9] Task B: ΔMain-lobe=37.26 dB, HPBW_elev≈12.70°, HPBW_az≈0.93°, SLL=-0.2 dB
# [Row 10] Task B: ΔMain-lobe=13.33 dB, HPBW_elev≈8.53°, HPBW_az≈3.62°, SLL=-0.6 dB
# [Row 11] Task B: ΔMain-lobe=8.37 dB, HPBW_elev≈10.85°, HPBW_az≈1.07°, SLL=-1.6 dB
# [Row 12] Task B: ΔMain-lobe=13.58 dB, HPBW_elev≈4.32°, HPBW_az≈3.45°, SLL=-0.9 dB
# [Row 13] Task B: ΔMain-lobe=21.77 dB, HPBW_elev≈15.25°, HPBW_az≈10.15°, SLL=-0.1 dB
# [Row 14] Task B: ΔMain-lobe=25.89 dB, HPBW_elev≈20.00°, HPBW_az≈9.47°, SLL=-0.1 dB
# [Row 15] Task B: ΔMain-lobe=6.71 dB, HPBW_elev≈5.38°, HPBW_az≈19.82°, SLL=-0.9 dB
# [Row 16] Task B: ΔMain-lobe=21.63 dB, HPBW_elev≈8.95°, HPBW_az≈17.70°, SLL=-6.5 dB
# [Row 17] Task B: ΔMain-lobe=23.82 dB, HPBW_elev≈13.52°, HPBW_az≈2.12°, SLL=-0.2 dB
# [Row 18] Task B: ΔMain-lobe=29.12 dB, HPBW_elev≈10.47°, HPBW_az≈1.60°, SLL=-1.9 dB
# [Row 19] Task B: ΔMain-lobe=25.78 dB, HPBW_elev≈16.65°, HPBW_az≈10.90°, SLL=-1.6 dB
# [Row 20] Task B: ΔMain-lobe=20.33 dB, HPBW_elev≈20.00°, HPBW_az≈10.35°, SLL=-0.6 dB
# [Row 21] Task B: ΔMain-lobe=109.85 dB, HPBW_elev≈20.00°, HPBW_az≈14.62°, SLL=-0.3 dB
# [Row 22] Task B: ΔMain-lobe=44.20 dB, HPBW_elev≈20.00°, HPBW_az≈19.62°, SLL=-0.6 dB
# [Row 23] Task B: ΔMain-lobe=26.45 dB, HPBW_elev≈3.85°, HPBW_az≈1.50°, SLL=-0.9 dB
# [Row 24] Task B: ΔMain-lobe=4.50 dB, HPBW_elev≈20.00°, HPBW_az≈2.62°, SLL=-0.7 dB
# [Row 25] Task B: ΔMain-lobe=64.71 dB, HPBW_elev≈5.00°, HPBW_az≈6.12°, SLL=-0.2 dB
# [Row 26] Task B: ΔMain-lobe=31.99 dB, HPBW_elev≈13.20°, HPBW_az≈13.80°, SLL=-0.6 dB
# [Row 27] Task B: ΔMain-lobe=25.27 dB, HPBW_elev≈20.00°, HPBW_az≈12.45°, SLL=-0.2 dB
# [Row 28] Task B: ΔMain-lobe=26.34 dB, HPBW_elev≈18.67°, HPBW_az≈14.68°, SLL=-1.2 dB
# [Row 29] Task B: ΔMain-lobe=-8.18 dB, HPBW_elev≈2.70°, HPBW_az≈17.83°, SLL=-1.0 dB
# [Row 30] Task B: ΔMain-lobe=59.66 dB, HPBW_elev≈9.12°, HPBW_az≈18.90°, SLL=-0.5 dB
# [Row 31] Task B: ΔMain-lobe=25.77 dB, HPBW_elev≈19.75°, HPBW_az≈1.45°, SLL=-2.1 dB
# [Row 32] Task B: ΔMain-lobe=14.31 dB, HPBW_elev≈18.72°, HPBW_az≈18.92°, SLL=-5.2 dB
# [Row 33] Task B: ΔMain-lobe=44.77 dB, HPBW_elev≈11.18°, HPBW_az≈1.53°, SLL=-0.8 dB
# [Row 34] Task B: ΔMain-lobe=34.03 dB, HPBW_elev≈3.57°, HPBW_az≈1.77°, SLL=-0.2 dB
# [Row 35] Task B: ΔMain-lobe=37.17 dB, HPBW_elev≈20.00°, HPBW_az≈9.88°, SLL=-0.4 dB
# [Row 36] Task B: ΔMain-lobe=52.85 dB, HPBW_elev≈12.20°, HPBW_az≈9.65°, SLL=-0.3 dB
# [Row 37] Task B: ΔMain-lobe=38.78 dB, HPBW_elev≈7.18°, HPBW_az≈7.30°, SLL=-1.8 dB
# [Row 38] Task B: ΔMain-lobe=30.08 dB, HPBW_elev≈4.30°, HPBW_az≈17.72°, SLL=-1.1 dB
# [Row 39] Task B: ΔMain-lobe=42.99 dB, HPBW_elev≈3.57°, HPBW_az≈16.53°, SLL=-0.8 dB
# [Row 40] Task B: ΔMain-lobe=-2.37 dB, HPBW_elev≈1.25°, HPBW_az≈10.95°, SLL=-0.1 dB
# [Row 41] Task B: ΔMain-lobe=55.59 dB, HPBW_elev≈20.00°, HPBW_az≈8.32°, SLL=-2.1 dB
# [Row 42] Task B: ΔMain-lobe=68.78 dB, HPBW_elev≈10.75°, HPBW_az≈8.40°, SLL=-0.2 dB
# [Row 43] Task B: ΔMain-lobe=45.26 dB, HPBW_elev≈12.88°, HPBW_az≈8.72°, SLL=-0.1 dB
# [Row 44] Task B: ΔMain-lobe=60.88 dB, HPBW_elev≈8.20°, HPBW_az≈16.95°, SLL=-1.5 dB
# [Row 45] Task B: ΔMain-lobe=59.62 dB, HPBW_elev≈10.68°, HPBW_az≈9.47°, SLL=-1.4 dB
# [Row 46] Task B: ΔMain-lobe=52.10 dB, HPBW_elev≈8.95°, HPBW_az≈7.20°, SLL=-2.8 dB
# [Row 47] Task B: ΔMain-lobe=101.51 dB, HPBW_elev≈17.55°, HPBW_az≈19.43°, SLL=-1.4 dB
# [Row 48] Task B: ΔMain-lobe=38.00 dB, HPBW_elev≈14.40°, HPBW_az≈5.62°, SLL=-0.0 dB
# [Row 49] Task B: ΔMain-lobe=114.84 dB, HPBW_elev≈20.00°, HPBW_az≈15.15°, SLL=-1.4 dB
# [Row 50] Task B: ΔMain-lobe=59.53 dB, HPBW_elev≈17.18°, HPBW_az≈18.43°, SLL=-0.0 dB
# [Row 51] Task B: ΔMain-lobe=73.87 dB, HPBW_elev≈13.68°, HPBW_az≈17.92°, SLL=-1.9 dB
# [Row 52] Task B: ΔMain-lobe=68.50 dB, HPBW_elev≈19.95°, HPBW_az≈10.65°, SLL=-2.2 dB
# [Row 53] Task B: ΔMain-lobe=60.06 dB, HPBW_elev≈20.00°, HPBW_az≈12.62°, SLL=-0.8 dB
# [Row 54] Task B: ΔMain-lobe=77.80 dB, HPBW_elev≈20.00°, HPBW_az≈19.75°, SLL=-0.9 dB
# [Row 55] Task B: ΔMain-lobe=81.56 dB, HPBW_elev≈17.97°, HPBW_az≈12.68°, SLL=-0.6 dB
# [Row 56] Task B: ΔMain-lobe=74.67 dB, HPBW_elev≈20.00°, HPBW_az≈18.40°, SLL=-2.1 dB
# [Row 57] Task B: ΔMain-lobe=77.03 dB, HPBW_elev≈20.00°, HPBW_az≈12.85°, SLL=-1.5 dB
# [Row 58] Task B: ΔMain-lobe=47.81 dB, HPBW_elev≈14.50°, HPBW_az≈18.45°, SLL=-3.1 dB
# [Row 59] Task B: ΔMain-lobe=71.61 dB, HPBW_elev≈2.55°, HPBW_az≈7.28°, SLL=-0.8 dB
# [Row 60] Task B: ΔMain-lobe=66.05 dB, HPBW_elev≈17.78°, HPBW_az≈10.07°, SLL=-0.2 dB
# [Row 61] Task B: ΔMain-lobe=98.56 dB, HPBW_elev≈5.85°, HPBW_az≈20.00°, SLL=-0.9 dB
# [Row 62] Task B: ΔMain-lobe=54.38 dB, HPBW_elev≈2.48°, HPBW_az≈20.00°, SLL=-2.4 dB
# [Row 63] Task B: ΔMain-lobe=46.05 dB, HPBW_elev≈20.00°, HPBW_az≈9.68°, SLL=-1.5 dB
# [Row 64] Task B: ΔMain-lobe=70.73 dB, HPBW_elev≈8.05°, HPBW_az≈14.18°, SLL=-0.3 dB
# [Row 65] Task B: ΔMain-lobe=105.23 dB, HPBW_elev≈20.00°, HPBW_az≈18.17°, SLL=-1.9 dB
# [Row 66] Task B: ΔMain-lobe=45.39 dB, HPBW_elev≈2.85°, HPBW_az≈4.05°, SLL=-2.9 dB
# [Row 67] Task B: ΔMain-lobe=36.54 dB, HPBW_elev≈20.00°, HPBW_az≈17.60°, SLL=-2.9 dB
# [Row 68] Task B: ΔMain-lobe=110.56 dB, HPBW_elev≈19.18°, HPBW_az≈4.75°, SLL=-0.6 dB
# [Row 69] Task B: ΔMain-lobe=49.55 dB, HPBW_elev≈15.90°, HPBW_az≈16.15°, SLL=-2.7 dB
# [Row 70] Task B: ΔMain-lobe=106.65 dB, HPBW_elev≈1.08°, HPBW_az≈7.45°, SLL=-1.7 dB
# [Row 71] Task B: ΔMain-lobe=44.51 dB, HPBW_elev≈14.22°, HPBW_az≈1.62°, SLL=-1.0 dB
# [Row 72] Task B: ΔMain-lobe=48.42 dB, HPBW_elev≈4.62°, HPBW_az≈1.32°, SLL=-0.4 dB
# [Row 73] Task B: ΔMain-lobe=60.39 dB, HPBW_elev≈5.20°, HPBW_az≈11.70°, SLL=-0.9 dB
# [Row 74] Task B: ΔMain-lobe=135.17 dB, HPBW_elev≈9.27°, HPBW_az≈12.15°, SLL=-0.1 dB
# [Row 75] Task B: ΔMain-lobe=82.49 dB, HPBW_elev≈7.50°, HPBW_az≈17.15°, SLL=-0.2 dB
# [Row 76] Task B: ΔMain-lobe=45.10 dB, HPBW_elev≈15.32°, HPBW_az≈1.42°, SLL=-0.4 dB
# [Row 77] Task B: ΔMain-lobe=95.15 dB, HPBW_elev≈17.43°, HPBW_az≈13.15°, SLL=-1.4 dB
# [Row 78] Task B: ΔMain-lobe=77.54 dB, HPBW_elev≈18.80°, HPBW_az≈15.73°, SLL=-0.4 dB
# [Row 79] Task B: ΔMain-lobe=51.01 dB, HPBW_elev≈5.28°, HPBW_az≈16.43°, SLL=-1.8 dB
# [Row 80] Task B: ΔMain-lobe=105.70 dB, HPBW_elev≈12.45°, HPBW_az≈19.87°, SLL=-0.6 dB
# [Row 81] Task B: ΔMain-lobe=86.01 dB, HPBW_elev≈20.00°, HPBW_az≈1.38°, SLL=-0.5 dB
# [Row 82] Task B: ΔMain-lobe=48.16 dB, HPBW_elev≈20.00°, HPBW_az≈6.30°, SLL=-0.1 dB
# [Row 83] Task B: ΔMain-lobe=47.34 dB, HPBW_elev≈7.88°, HPBW_az≈17.90°, SLL=-1.7 dB
# [Row 84] Task B: ΔMain-lobe=84.06 dB, HPBW_elev≈20.00°, HPBW_az≈19.82°, SLL=-0.3 dB
# [Row 85] Task B: ΔMain-lobe=104.47 dB, HPBW_elev≈20.00°, HPBW_az≈7.48°, SLL=-0.2 dB
# [Row 86] Task B: ΔMain-lobe=52.85 dB, HPBW_elev≈9.60°, HPBW_az≈15.90°, SLL=-0.3 dB
# [Row 87] Task B: ΔMain-lobe=55.44 dB, HPBW_elev≈5.40°, HPBW_az≈1.25°, SLL=-0.4 dB
# [Row 88] Task B: ΔMain-lobe=73.20 dB, HPBW_elev≈2.45°, HPBW_az≈10.98°, SLL=-3.3 dB
# [Row 89] Task B: ΔMain-lobe=31.59 dB, HPBW_elev≈3.73°, HPBW_az≈16.67°, SLL=-0.3 dB
# [Row 90] Task B: ΔMain-lobe=103.61 dB, HPBW_elev≈20.00°, HPBW_az≈3.55°, SLL=-0.2 dB
# [Row 91] Task B: ΔMain-lobe=37.16 dB, HPBW_elev≈2.33°, HPBW_az≈1.35°, SLL=-1.5 dB
# [Row 92] Task B: ΔMain-lobe=52.46 dB, HPBW_elev≈14.53°, HPBW_az≈14.65°, SLL=-1.1 dB
# [Row 93] Task B: ΔMain-lobe=118.53 dB, HPBW_elev≈4.57°, HPBW_az≈8.70°, SLL=-0.2 dB
# [Row 94] Task B: ΔMain-lobe=66.57 dB, HPBW_elev≈14.35°, HPBW_az≈13.78°, SLL=-2.1 dB
# [Row 95] Task B: ΔMain-lobe=72.14 dB, HPBW_elev≈14.73°, HPBW_az≈11.80°, SLL=-0.0 dB
# [Row 96] Task B: ΔMain-lobe=73.31 dB, HPBW_elev≈4.68°, HPBW_az≈16.65°, SLL=-2.0 dB
# [Row 97] Task B: ΔMain-lobe=130.35 dB, HPBW_elev≈20.00°, HPBW_az≈3.03°, SLL=-0.9 dB
# [Row 98] Task B: ΔMain-lobe=103.67 dB, HPBW_elev≈20.00°, HPBW_az≈5.65°, SLL=-0.3 dB
# [Row 99] Task B: ΔMain-lobe=44.27 dB, HPBW_elev≈3.15°, HPBW_az≈20.00°, SLL=-0.4 dB
# [Row 100] Task B: ΔMain-lobe=113.61 dB, HPBW_elev≈3.88°, HPBW_az≈3.45°, SLL=-0.1 dB
# [Row 101] Task B: ΔMain-lobe=116.89 dB, HPBW_elev≈16.33°, HPBW_az≈20.00°, SLL=-3.8 dB
# [Row 102] Task B: ΔMain-lobe=96.01 dB, HPBW_elev≈17.55°, HPBW_az≈10.03°, SLL=-1.2 dB
# [Row 103] Task B: ΔMain-lobe=42.93 dB, HPBW_elev≈20.00°, HPBW_az≈1.35°, SLL=-0.6 dB
# [Row 104] Task B: ΔMain-lobe=119.67 dB, HPBW_elev≈20.00°, HPBW_az≈16.00°, SLL=-1.4 dB
# [Row 105] Task B: ΔMain-lobe=78.87 dB, HPBW_elev≈7.57°, HPBW_az≈1.35°, SLL=-0.3 dB
# [Row 106] Task B: ΔMain-lobe=30.17 dB, HPBW_elev≈20.00°, HPBW_az≈11.47°, SLL=-0.1 dB
# [Row 107] Task B: ΔMain-lobe=22.07 dB, HPBW_elev≈14.67°, HPBW_az≈16.62°, SLL=-0.2 dB
# [Row 108] Task B: ΔMain-lobe=114.60 dB, HPBW_elev≈12.22°, HPBW_az≈14.62°, SLL=-1.4 dB
# [Row 109] Task B: ΔMain-lobe=71.01 dB, HPBW_elev≈3.02°, HPBW_az≈16.62°, SLL=-1.7 dB
# [Row 110] Task B: ΔMain-lobe=116.28 dB, HPBW_elev≈3.28°, HPBW_az≈13.97°, SLL=-1.1 dB
# [Row 111] Task B: ΔMain-lobe=116.85 dB, HPBW_elev≈20.00°, HPBW_az≈18.62°, SLL=-0.3 dB
# [Row 112] Task B: ΔMain-lobe=85.01 dB, HPBW_elev≈18.05°, HPBW_az≈2.33°, SLL=-4.8 dB
# [Row 113] Task B: ΔMain-lobe=64.98 dB, HPBW_elev≈18.95°, HPBW_az≈9.70°, SLL=-0.7 dB
# [Row 114] Task B: ΔMain-lobe=47.07 dB, HPBW_elev≈20.00°, HPBW_az≈16.95°, SLL=-0.9 dB
# [Row 115] Task B: ΔMain-lobe=98.61 dB, HPBW_elev≈7.68°, HPBW_az≈3.72°, SLL=-3.1 dB
# [Row 116] Task B: ΔMain-lobe=28.91 dB, HPBW_elev≈8.65°, HPBW_az≈18.23°, SLL=-0.8 dB
# [Row 117] Task B: ΔMain-lobe=96.79 dB, HPBW_elev≈5.60°, HPBW_az≈12.62°, SLL=-0.6 dB
# [Row 118] Task B: ΔMain-lobe=120.45 dB, HPBW_elev≈20.00°, HPBW_az≈3.75°, SLL=-0.1 dB
# [Row 119] Task B: ΔMain-lobe=46.38 dB, HPBW_elev≈20.00°, HPBW_az≈1.25°, SLL=-0.1 dB
# [Row 120] Task B: ΔMain-lobe=96.38 dB, HPBW_elev≈4.22°, HPBW_az≈13.92°, SLL=-0.2 dB
# [Row 121] Task B: ΔMain-lobe=36.01 dB, HPBW_elev≈2.42°, HPBW_az≈16.08°, SLL=-0.7 dB
# [Row 122] Task B: ΔMain-lobe=112.69 dB, HPBW_elev≈9.40°, HPBW_az≈4.05°, SLL=-0.6 dB
# [Row 123] Task B: ΔMain-lobe=102.61 dB, HPBW_elev≈4.40°, HPBW_az≈3.83°, SLL=-0.5 dB
# [Row 124] Task B: ΔMain-lobe=95.66 dB, HPBW_elev≈14.75°, HPBW_az≈3.65°, SLL=-0.6 dB
# [Row 125] Task B: ΔMain-lobe=75.10 dB, HPBW_elev≈2.92°, HPBW_az≈17.03°, SLL=-0.2 dB
# [Row 126] Task B: ΔMain-lobe=113.13 dB, HPBW_elev≈20.00°, HPBW_az≈10.83°, SLL=-0.4 dB
# [Row 127] Task B: ΔMain-lobe=77.03 dB, HPBW_elev≈10.95°, HPBW_az≈15.40°, SLL=-0.2 dB
# [Row 128] Task B: ΔMain-lobe=125.24 dB, HPBW_elev≈20.00°, HPBW_az≈20.00°, SLL=-0.2 dB
# [Row 129] Task B: ΔMain-lobe=130.86 dB, HPBW_elev≈8.35°, HPBW_az≈19.55°, SLL=-4.4 dB
# [Row 130] Task B: ΔMain-lobe=86.40 dB, HPBW_elev≈20.00°, HPBW_az≈14.10°, SLL=-1.3 dB
# [Row 131] Task B: ΔMain-lobe=120.23 dB, HPBW_elev≈18.90°, HPBW_az≈14.07°, SLL=-3.2 dB
# [Row 132] Task B: ΔMain-lobe=117.69 dB, HPBW_elev≈20.00°, HPBW_az≈12.25°, SLL=-0.3 dB
# [Row 133] Task B: ΔMain-lobe=112.50 dB, HPBW_elev≈16.88°, HPBW_az≈11.35°, SLL=-2.9 dB
# [Row 134] Task B: ΔMain-lobe=108.71 dB, HPBW_elev≈20.00°, HPBW_az≈19.62°, SLL=-0.8 dB
# [Row 135] Task B: ΔMain-lobe=73.51 dB, HPBW_elev≈2.35°, HPBW_az≈10.07°, SLL=-3.4 dB
# [Row 136] Task B: ΔMain-lobe=54.53 dB, HPBW_elev≈0.52°, HPBW_az≈9.88°, SLL=-5.1 dB
# [Row 137] Task B: ΔMain-lobe=116.85 dB, HPBW_elev≈20.00°, HPBW_az≈18.28°, SLL=-0.2 dB
# [Row 138] Task B: ΔMain-lobe=59.73 dB, HPBW_elev≈16.53°, HPBW_az≈11.60°, SLL=-6.5 dB
# [Row 139] Task B: ΔMain-lobe=119.97 dB, HPBW_elev≈20.00°, HPBW_az≈10.52°, SLL=-2.5 dB
# [Row 140] Task B: ΔMain-lobe=82.45 dB, HPBW_elev≈5.90°, HPBW_az≈3.80°, SLL=-1.3 dB
# [Row 141] Task B: ΔMain-lobe=127.42 dB, HPBW_elev≈20.00°, HPBW_az≈2.88°, SLL=-1.9 dB
# [Row 142] Task B: ΔMain-lobe=135.06 dB, HPBW_elev≈7.80°, HPBW_az≈20.00°, SLL=-0.5 dB
# [Row 143] Task B: ΔMain-lobe=114.60 dB, HPBW_elev≈20.00°, HPBW_az≈20.00°, SLL=-1.6 dB
# [Row 144] Task B: ΔMain-lobe=69.87 dB, HPBW_elev≈20.00°, HPBW_az≈6.03°, SLL=-0.1 dB
# [Row 145] Task B: ΔMain-lobe=96.41 dB, HPBW_elev≈20.00°, HPBW_az≈16.10°, SLL=-0.1 dB
# [Row 146] Task B: ΔMain-lobe=118.11 dB, HPBW_elev≈5.00°, HPBW_az≈18.67°, SLL=-1.6 dB
# [Row 147] Task B: ΔMain-lobe=95.65 dB, HPBW_elev≈16.05°, HPBW_az≈14.08°, SLL=-8.0 dB
# [Row 148] Task B: ΔMain-lobe=95.38 dB, HPBW_elev≈20.00°, HPBW_az≈16.33°, SLL=-1.0 dB
# [Row 149] Task B: ΔMain-lobe=119.26 dB, HPBW_elev≈9.07°, HPBW_az≈14.15°, SLL=-0.6 dB
# [Row 150] Task B: ΔMain-lobe=31.58 dB, HPBW_elev≈3.42°, HPBW_az≈10.85°, SLL=-5.2 dB
# [Row 151] Task B: ΔMain-lobe=112.53 dB, HPBW_elev≈15.45°, HPBW_az≈7.90°, SLL=-0.4 dB
# [Row 152] Task B: ΔMain-lobe=51.31 dB, HPBW_elev≈5.22°, HPBW_az≈15.20°, SLL=-1.0 dB
# [Row 153] Task B: ΔMain-lobe=112.44 dB, HPBW_elev≈9.32°, HPBW_az≈10.30°, SLL=-1.8 dB
# [Row 154] Task B: ΔMain-lobe=95.52 dB, HPBW_elev≈16.80°, HPBW_az≈8.53°, SLL=-1.1 dB
# [Row 155] Task B: ΔMain-lobe=94.19 dB, HPBW_elev≈9.12°, HPBW_az≈9.88°, SLL=-3.4 dB
# [Row 156] Task B: ΔMain-lobe=115.27 dB, HPBW_elev≈9.95°, HPBW_az≈6.47°, SLL=-3.6 dB
# [Row 157] Task B: ΔMain-lobe=117.19 dB, HPBW_elev≈15.52°, HPBW_az≈15.88°, SLL=-0.4 dB
# [Row 158] Task B: ΔMain-lobe=104.44 dB, HPBW_elev≈7.02°, HPBW_az≈16.10°, SLL=-0.2 dB
# [Row 159] Task B: ΔMain-lobe=80.50 dB, HPBW_elev≈7.45°, HPBW_az≈1.53°, SLL=-0.7 dB
# [Row 160] Task B: ΔMain-lobe=77.99 dB, HPBW_elev≈14.40°, HPBW_az≈3.03°, SLL=-0.6 dB
# [Row 161] Task B: ΔMain-lobe=97.20 dB, HPBW_elev≈1.65°, HPBW_az≈11.80°, SLL=-0.4 dB
# [Row 162] Task B: ΔMain-lobe=132.21 dB, HPBW_elev≈9.40°, HPBW_az≈10.68°, SLL=-0.2 dB
# [Row 163] Task B: ΔMain-lobe=115.42 dB, HPBW_elev≈9.40°, HPBW_az≈18.52°, SLL=-0.3 dB
# [Row 164] Task B: ΔMain-lobe=60.02 dB, HPBW_elev≈15.22°, HPBW_az≈19.40°, SLL=-0.2 dB
# [Row 165] Task B: ΔMain-lobe=80.16 dB, HPBW_elev≈20.00°, HPBW_az≈19.85°, SLL=-0.0 dB
# [Row 166] Task B: ΔMain-lobe=130.98 dB, HPBW_elev≈8.65°, HPBW_az≈13.05°, SLL=-0.5 dB
# [Row 167] Task B: ΔMain-lobe=124.61 dB, HPBW_elev≈20.00°, HPBW_az≈20.00°, SLL=-0.1 dB
# [Row 168] Task B: ΔMain-lobe=118.18 dB, HPBW_elev≈20.00°, HPBW_az≈17.47°, SLL=-3.3 dB
# [Row 169] Task B: ΔMain-lobe=123.42 dB, HPBW_elev≈9.08°, HPBW_az≈20.00°, SLL=-0.2 dB
# [Row 170] Task B: ΔMain-lobe=106.83 dB, HPBW_elev≈9.57°, HPBW_az≈3.53°, SLL=-0.5 dB
# [Row 171] Task B: ΔMain-lobe=96.28 dB, HPBW_elev≈9.02°, HPBW_az≈18.10°, SLL=-0.0 dB
# [Row 172] Task B: ΔMain-lobe=114.75 dB, HPBW_elev≈15.20°, HPBW_az≈4.12°, SLL=-0.3 dB
# [Row 173] Task B: ΔMain-lobe=133.14 dB, HPBW_elev≈20.00°, HPBW_az≈5.50°, SLL=-0.1 dB
# [Row 174] Task B: ΔMain-lobe=18.41 dB, HPBW_elev≈5.95°, HPBW_az≈13.38°, SLL=-0.0 dB
# [Row 175] Task B: ΔMain-lobe=116.90 dB, HPBW_elev≈17.53°, HPBW_az≈7.55°, SLL=-1.1 dB
# [Row 176] Task B: ΔMain-lobe=123.47 dB, HPBW_elev≈10.57°, HPBW_az≈8.58°, SLL=-2.4 dB
# [Row 177] Task B: ΔMain-lobe=121.24 dB, HPBW_elev≈20.00°, HPBW_az≈15.68°, SLL=-0.9 dB
# [Row 178] Task B: ΔMain-lobe=118.75 dB, HPBW_elev≈20.00°, HPBW_az≈19.12°, SLL=-1.1 dB
# [Row 179] Task B: ΔMain-lobe=117.36 dB, HPBW_elev≈20.00°, HPBW_az≈3.65°, SLL=-1.0 dB
# [Row 180] Task B: ΔMain-lobe=47.07 dB, HPBW_elev≈1.07°, HPBW_az≈18.40°, SLL=-1.3 dB
# [Row 181] Task B: ΔMain-lobe=55.60 dB, HPBW_elev≈20.00°, HPBW_az≈12.68°, SLL=-1.4 dB
# [Row 182] Task B: ΔMain-lobe=67.62 dB, HPBW_elev≈20.00°, HPBW_az≈2.45°, SLL=-8.8 dB
# [Row 183] Task B: ΔMain-lobe=51.17 dB, HPBW_elev≈4.65°, HPBW_az≈14.57°, SLL=-0.5 dB
# [Row 184] Task B: ΔMain-lobe=110.43 dB, HPBW_elev≈20.00°, HPBW_az≈16.05°, SLL=-1.0 dB
# [Row 185] Task B: ΔMain-lobe=67.54 dB, HPBW_elev≈14.75°, HPBW_az≈1.22°, SLL=-0.1 dB
# [Row 186] Task B: ΔMain-lobe=123.63 dB, HPBW_elev≈16.53°, HPBW_az≈4.47°, SLL=-4.5 dB
# [Row 187] Task B: ΔMain-lobe=111.42 dB, HPBW_elev≈15.12°, HPBW_az≈17.55°, SLL=-0.2 dB
# [Row 188] Task B: ΔMain-lobe=109.94 dB, HPBW_elev≈1.70°, HPBW_az≈6.15°, SLL=-4.5 dB
# [Row 189] Task B: ΔMain-lobe=127.61 dB, HPBW_elev≈17.83°, HPBW_az≈8.45°, SLL=-4.5 dB
# [Row 190] Task B: ΔMain-lobe=133.68 dB, HPBW_elev≈20.00°, HPBW_az≈5.70°, SLL=-3.0 dB
# [Row 191] Task B: ΔMain-lobe=111.09 dB, HPBW_elev≈6.22°, HPBW_az≈3.95°, SLL=-0.1 dB
# [Row 192] Task B: ΔMain-lobe=56.64 dB, HPBW_elev≈18.42°, HPBW_az≈1.68°, SLL=-0.3 dB
# [Row 193] Task B: ΔMain-lobe=100.99 dB, HPBW_elev≈20.00°, HPBW_az≈17.60°, SLL=-1.4 dB
# [Row 194] Task B: ΔMain-lobe=83.03 dB, HPBW_elev≈13.73°, HPBW_az≈16.88°, SLL=-14.8 dB
# [Row 195] Task B: ΔMain-lobe=65.65 dB, HPBW_elev≈14.03°, HPBW_az≈18.65°, SLL=-0.2 dB
# [Row 196] Task B: ΔMain-lobe=100.34 dB, HPBW_elev≈4.97°, HPBW_az≈18.25°, SLL=-0.5 dB
# [Row 197] Task B: ΔMain-lobe=65.11 dB, HPBW_elev≈14.92°, HPBW_az≈20.00°, SLL=-0.4 dB
# [Row 198] Task B: ΔMain-lobe=115.85 dB, HPBW_elev≈14.97°, HPBW_az≈17.03°, SLL=-0.1 dB
# [Row 199] Task B: ΔMain-lobe=99.36 dB, HPBW_elev≈4.35°, HPBW_az≈16.82°, SLL=-4.9 dB
# [Row 200] Task B: ΔMain-lobe=111.77 dB, HPBW_elev≈7.88°, HPBW_az≈6.35°, SLL=-1.3 dB
# [Row 201] Task B: ΔMain-lobe=70.60 dB, HPBW_elev≈17.62°, HPBW_az≈17.43°, SLL=-0.7 dB
# [Row 202] Task B: ΔMain-lobe=120.17 dB, HPBW_elev≈8.25°, HPBW_az≈9.22°, SLL=-0.4 dB
# [Row 203] Task B: ΔMain-lobe=109.60 dB, HPBW_elev≈16.40°, HPBW_az≈18.72°, SLL=-0.0 dB
# [Row 204] Task B: ΔMain-lobe=62.31 dB, HPBW_elev≈5.17°, HPBW_az≈18.78°, SLL=-0.0 dB
# [Row 205] Task B: ΔMain-lobe=116.57 dB, HPBW_elev≈6.90°, HPBW_az≈16.10°, SLL=-0.1 dB
# [Row 206] Task B: ΔMain-lobe=119.61 dB, HPBW_elev≈7.95°, HPBW_az≈17.75°, SLL=-0.0 dB
# [Row 207] Task B: ΔMain-lobe=89.27 dB, HPBW_elev≈20.00°, HPBW_az≈17.32°, SLL=-0.3 dB
# [Row 208] Task B: ΔMain-lobe=105.76 dB, HPBW_elev≈8.95°, HPBW_az≈15.62°, SLL=-4.5 dB
# [Row 209] Task B: ΔMain-lobe=102.50 dB, HPBW_elev≈6.82°, HPBW_az≈15.45°, SLL=-2.2 dB
# [Row 210] Task B: ΔMain-lobe=103.22 dB, HPBW_elev≈2.00°, HPBW_az≈12.70°, SLL=-1.1 dB
# [Row 211] Task B: ΔMain-lobe=108.26 dB, HPBW_elev≈19.60°, HPBW_az≈15.28°, SLL=-0.6 dB
# [Row 212] Task B: ΔMain-lobe=99.72 dB, HPBW_elev≈5.25°, HPBW_az≈1.67°, SLL=-0.9 dB
# [Row 213] Task B: ΔMain-lobe=102.74 dB, HPBW_elev≈16.33°, HPBW_az≈16.12°, SLL=-6.7 dB
# [Row 214] Task B: ΔMain-lobe=119.38 dB, HPBW_elev≈8.47°, HPBW_az≈18.72°, SLL=-5.4 dB
# [Row 215] Task B: ΔMain-lobe=115.85 dB, HPBW_elev≈9.17°, HPBW_az≈15.75°, SLL=-5.6 dB
# [Row 216] Task B: ΔMain-lobe=90.97 dB, HPBW_elev≈18.05°, HPBW_az≈15.92°, SLL=-0.0 dB
# [Row 217] Task B: ΔMain-lobe=140.18 dB, HPBW_elev≈17.75°, HPBW_az≈4.20°, SLL=-4.7 dB
# [Row 218] Task B: ΔMain-lobe=81.23 dB, HPBW_elev≈6.62°, HPBW_az≈11.50°, SLL=-0.6 dB
# [Row 219] Task B: ΔMain-lobe=74.84 dB, HPBW_elev≈19.92°, HPBW_az≈11.75°, SLL=-0.9 dB
# [Row 220] Task B: ΔMain-lobe=61.80 dB, HPBW_elev≈17.92°, HPBW_az≈14.65°, SLL=-13.6 dB
# [Row 221] Task B: ΔMain-lobe=135.31 dB, HPBW_elev≈5.35°, HPBW_az≈18.25°, SLL=-5.2 dB
# [Row 222] Task B: ΔMain-lobe=111.73 dB, HPBW_elev≈18.98°, HPBW_az≈18.45°, SLL=-0.2 dB
# [Row 223] Task B: ΔMain-lobe=114.95 dB, HPBW_elev≈10.42°, HPBW_az≈10.00°, SLL=-3.4 dB
# [Row 224] Task B: ΔMain-lobe=100.30 dB, HPBW_elev≈20.00°, HPBW_az≈15.85°, SLL=-0.6 dB
# [Row 225] Task B: ΔMain-lobe=122.25 dB, HPBW_elev≈12.70°, HPBW_az≈13.65°, SLL=-2.5 dB
# [Row 226] Task B: ΔMain-lobe=117.31 dB, HPBW_elev≈14.60°, HPBW_az≈17.45°, SLL=-0.1 dB
# [Row 227] Task B: ΔMain-lobe=80.93 dB, HPBW_elev≈9.93°, HPBW_az≈17.70°, SLL=-0.3 dB
# [Row 228] Task B: ΔMain-lobe=86.65 dB, HPBW_elev≈6.88°, HPBW_az≈16.92°, SLL=-14.5 dB
# [Row 229] Task B: ΔMain-lobe=121.38 dB, HPBW_elev≈20.00°, HPBW_az≈16.57°, SLL=-0.0 dB
# [Row 230] Task B: ΔMain-lobe=105.63 dB, HPBW_elev≈6.45°, HPBW_az≈6.55°, SLL=-0.3 dB
# [Row 231] Task B: ΔMain-lobe=92.63 dB, HPBW_elev≈5.80°, HPBW_az≈9.15°, SLL=-11.1 dB
# [Row 232] Task B: ΔMain-lobe=128.87 dB, HPBW_elev≈14.45°, HPBW_az≈20.00°, SLL=-0.1 dB
# [Row 233] Task B: ΔMain-lobe=143.49 dB, HPBW_elev≈8.65°, HPBW_az≈10.35°, SLL=-0.0 dB
# [Row 234] Task B: ΔMain-lobe=109.26 dB, HPBW_elev≈14.62°, HPBW_az≈14.62°, SLL=-0.0 dB
# [Row 235] Task B: ΔMain-lobe=133.94 dB, HPBW_elev≈12.70°, HPBW_az≈20.00°, SLL=-6.7 dB
# [Row 236] Task B: ΔMain-lobe=118.41 dB, HPBW_elev≈4.47°, HPBW_az≈3.12°, SLL=-2.9 dB
# [Row 237] Task B: ΔMain-lobe=113.78 dB, HPBW_elev≈2.62°, HPBW_az≈1.62°, SLL=-6.8 dB
# [Row 238] Task B: ΔMain-lobe=121.25 dB, HPBW_elev≈15.12°, HPBW_az≈8.83°, SLL=-4.5 dB
# [Row 239] Task B: ΔMain-lobe=93.14 dB, HPBW_elev≈20.00°, HPBW_az≈14.10°, SLL=-5.0 dB
# [Row 240] Task B: ΔMain-lobe=121.46 dB, HPBW_elev≈3.67°, HPBW_az≈9.38°, SLL=-5.4 dB
# [Row 241] Task B: ΔMain-lobe=90.87 dB, HPBW_elev≈4.65°, HPBW_az≈1.90°, SLL=-0.8 dB
# [Row 242] Task B: ΔMain-lobe=117.47 dB, HPBW_elev≈14.80°, HPBW_az≈11.80°, SLL=-8.7 dB
# [Row 243] Task B: ΔMain-lobe=89.78 dB, HPBW_elev≈16.27°, HPBW_az≈15.85°, SLL=-6.5 dB
# [Row 244] Task B: ΔMain-lobe=106.15 dB, HPBW_elev≈18.92°, HPBW_az≈2.57°, SLL=-0.1 dB
# [Row 245] Task B: ΔMain-lobe=91.64 dB, HPBW_elev≈20.00°, HPBW_az≈4.62°, SLL=-0.5 dB
# [Row 246] Task B: ΔMain-lobe=98.00 dB, HPBW_elev≈20.00°, HPBW_az≈6.00°, SLL=-0.7 dB
# [Row 247] Task B: ΔMain-lobe=101.23 dB, HPBW_elev≈20.00°, HPBW_az≈5.65°, SLL=-7.5 dB
# [Row 248] Task B: ΔMain-lobe=122.04 dB, HPBW_elev≈10.22°, HPBW_az≈3.70°, SLL=-9.2 dB
# [Row 249] Task B: ΔMain-lobe=111.88 dB, HPBW_elev≈15.45°, HPBW_az≈8.02°, SLL=-8.2 dB
# [Row 250] Task B: ΔMain-lobe=104.48 dB, HPBW_elev≈4.22°, HPBW_az≈18.03°, SLL=-2.2 dB
# [Row 251] Task B: ΔMain-lobe=111.81 dB, HPBW_elev≈7.30°, HPBW_az≈14.25°, SLL=-0.4 dB
# [Row 252] Task B: ΔMain-lobe=125.42 dB, HPBW_elev≈19.72°, HPBW_az≈10.12°, SLL=-9.2 dB
# [Row 253] Task B: ΔMain-lobe=115.34 dB, HPBW_elev≈20.00°, HPBW_az≈1.72°, SLL=-26.1 dB
# [Row 254] Task B: ΔMain-lobe=116.86 dB, HPBW_elev≈11.68°, HPBW_az≈4.95°, SLL=-0.7 dB
# [Row 255] Task B: ΔMain-lobe=117.72 dB, HPBW_elev≈20.00°, HPBW_az≈20.00°, SLL=-17.3 dB
#
# Directional Gain Comparison (Task A vs Task B)
# Idx | θ φ | GainA | GainB | Δ(B-A)
#   0 |  90.0  90.0 |  38.23 |  36.69 |  -1.55
#   1 |  92.5  86.3 |  -2.59 |  -3.99 |  -1.40
#   2 |  87.5  93.7 |  -2.59 |  -3.03 |  -0.44
#   3 |  92.8  93.6 |  -3.72 |   6.56 |  10.28
#   4 |  87.3  86.2 |  -2.06 |   4.75 |   6.81
#   5 |  84.8  89.8 |  36.16 |  33.50 |  -2.66
#   6 |  95.3  90.0 |  36.61 |  34.20 |  -2.41
#   7 |  90.3  97.3 |  -3.68 |  -0.32 |   3.36
#   8 |  89.9  82.6 | -25.19 |  -8.41 |  16.78
#   9 |  82.3  93.5 | -42.07 |  -4.82 |  37.26
#  10 |  97.8  86.3 | -14.40 |  -1.07 |  13.33
#  11 |  82.9  85.0 | -16.56 |  -8.19 |   8.37
#  12 |  98.1  93.6 | -21.79 |  -8.21 |  13.58
#  13 |  95.0  82.7 | -21.39 |   0.38 |  21.77
#  14 |  85.0  97.3 | -21.40 |   4.49 |  25.89
#  15 |  95.5  97.2 | -15.01 |  -8.30 |   6.71
#  16 |  85.4  81.4 | -26.31 |  -4.68 |  21.63
#  17 |  80.4  88.7 | -24.02 |  -0.20 |  23.82
#  18 | 100.5  89.9 |  -6.53 |  22.59 |  29.12
#  19 |  87.8 100.9 | -26.08 |  -0.29 |  25.78
#  20 |  93.0 100.8 | -24.79 |  -4.46 |  20.33
#  21 |  92.4  79.0 | -111.15 |  -1.30 | 109.85
#  22 |  88.0  77.9 | -55.60 | -11.39 |  44.20
#  23 |  77.9  92.3 | -33.83 |  -7.38 |  26.45
#  24 |  79.9  97.1 | -28.86 | -24.36 |   4.50
#  25 | 100.2  82.7 | -72.74 |  -8.03 |  64.71
#  26 | 100.7  97.2 | -29.04 |   2.95 |  31.99
#  27 |  78.7  83.7 | -25.13 |   0.14 |  25.27
#  28 |  97.4  79.1 | -38.24 | -11.90 |  26.34
#  29 |  82.6 100.9 | -13.47 | -21.65 |  -8.18
#  30 |  81.2  80.1 | -64.46 |  -4.80 |  59.66
#  31 | 102.9  86.2 | -26.72 |  -0.95 |  25.77
#  32 |  98.2 100.8 | -20.27 |  -5.96 |  14.31
#  33 | 103.2  93.5 | -48.02 |  -3.26 |  44.77
#  34 |  76.2  87.3 | -39.02 |  -4.98 |  34.03
#  35 |  90.5 104.3 | -43.21 |  -6.04 |  37.17
#  36 |  83.8  76.6 | -57.03 |  -4.18 |  52.85
#  37 |  85.4 104.3 | -48.33 |  -9.55 |  38.78
#  38 |  94.8  75.5 | -43.21 | -13.13 |  30.08
#  39 |  95.7 104.3 | -49.89 |  -6.90 |  42.99
#  40 | 105.5  89.9 |  -2.71 |  -5.08 |  -2.37
#  41 |  90.5  74.4 | -57.14 |  -1.56 |  55.59
#  42 |  75.6  95.9 | -68.28 |   0.50 |  68.78
#  43 |  73.8  90.9 | -46.31 |  -1.05 |  45.26
#  44 |  77.6 100.7 | -69.42 |  -8.55 |  60.88
#  45 | 102.5  79.1 | -60.27 |  -0.65 |  59.62
#  46 | 105.2  82.6 | -55.54 |  -3.43 |  52.10
#  47 | 103.2 100.7 | -111.11 |  -9.60 | 101.51
#  48 |  77.1  78.8 | -49.09 | -11.09 |  38.00
#  49 |  74.6  82.3 | -117.93 |  -3.10 | 114.84
#  50 | 105.6  97.1 | -68.55 |  -9.02 |  59.53
#  51 |  86.3  73.2 | -75.98 |  -2.11 |  73.87
#  52 |  99.7  75.7 | -71.76 |  -3.26 |  68.50
#  53 |  80.3 104.3 | -63.79 |  -3.73 |  60.06
#  54 | 100.7 104.2 | -85.97 |  -8.17 |  77.80
#  55 |  88.1 107.7 | -87.50 |  -5.94 |  81.56
#  56 |  79.7  75.3 | -81.78 |  -7.11 |  74.67
#  57 |  93.2 107.7 | -79.06 |  -2.03 |  77.03
#  58 | 107.8  86.2 | -58.44 | -10.62 |  47.81
#  59 |  72.2  85.9 | -76.16 |  -4.55 |  71.61
#  60 | 108.0  93.5 | -75.47 |  -9.42 |  66.05
#  61 |  83.1 107.7 | -104.37 |  -5.81 |  98.56
#  62 |  71.5  94.6 | -63.53 |  -9.14 |  54.38
#  63 |  92.9  71.1 | -44.13 |   1.92 |  46.05
#  64 |  73.4  99.5 | -75.63 |  -4.91 |  70.73
#  65 |  97.1  72.2 | -108.81 |  -3.58 | 105.23
#  66 |  98.2 107.6 | -55.58 | -10.19 |  45.39
#  67 |  82.3  72.0 | -43.78 |  -7.24 |  36.54
#  68 |  88.8  70.0 | -114.19 |  -3.63 | 110.56
#  69 |  69.9  89.6 | -50.07 |  -0.52 |  49.55
#  70 |  75.4 104.1 | -112.88 |  -6.23 | 106.65
#  71 | 110.3  89.8 | -54.50 |  -9.99 |  44.51
#  72 | 107.3  79.1 | -53.64 |  -5.22 |  48.42
#  73 | 104.6  75.6 | -73.56 | -13.17 |  60.39
#  74 |  73.2  77.5 | -136.04 |  -0.86 | 135.17
#  75 | 108.0 100.6 | -82.09 |   0.40 |  82.49
#  76 | 105.5 104.1 | -49.97 |  -4.86 |  45.10
#  77 |  90.8 110.9 | -101.87 |  -6.72 |  95.15
#  78 |  70.8  81.0 | -80.90 |  -3.36 |  77.54
#  79 | 109.9  82.6 | -54.40 |  -3.39 |  51.01
#  80 | 101.9  72.3 | -104.58 |   1.12 | 105.70
#  81 |  78.1 107.7 | -94.14 |  -8.14 |  86.01
#  82 |  75.8  74.1 | -52.91 |  -4.75 |  48.16
#  83 |  85.8 110.9 | -54.96 |  -7.62 |  47.34
#  84 | 110.3  97.0 | -83.41 |   0.65 |  84.06
#  85 |  95.7 110.9 | -110.45 |  -5.99 | 104.47
#  86 | 103.0 107.5 | -57.55 |  -4.71 |  52.85
#  87 |  84.8  68.8 | -73.58 | -18.14 |  55.44
#  88 |  69.4  98.1 | -82.10 |  -8.90 |  73.20
#  89 |  68.4  84.6 | -53.23 | -21.64 |  31.59
#  90 |  78.3  70.8 | -112.83 |  -9.22 | 103.61
#  91 |  67.7  93.2 | -44.39 |  -7.22 |  37.16
#  92 |  95.2  68.0 | -55.64 |  -3.18 |  52.46
#  93 |  71.3 103.0 | -132.05 | -13.51 | 118.53
#  94 | 112.3  86.1 | -70.52 |  -3.95 |  66.57
#  95 |  80.9 110.9 | -68.82 |   3.32 |  72.14
#  96 | 112.6  93.4 | -83.57 | -10.26 |  73.31
#  97 |  99.3  69.0 | -134.01 |  -3.66 | 130.35
#  98 |  91.2  66.9 | -106.39 |  -2.72 | 103.67
#  99 | 100.5 110.8 | -81.06 | -36.79 |  44.27
# 100 | 109.2  75.6 | -118.35 |  -4.74 | 113.61
# 101 |  73.4 107.5 | -123.82 |  -6.93 | 116.89
# 102 |  66.2  88.2 | -96.56 |  -0.55 |  96.01
# 103 |  80.9  67.7 | -45.76 |  -2.83 |  42.93
# 104 |  88.5 114.0 | -127.64 |  -7.97 | 119.67
# 105 | 106.6  72.3 | -84.01 |  -5.14 |  78.87
# 106 |  93.3 114.0 | -57.75 | -27.58 |  30.17
# 107 | 111.8  79.0 | -25.05 |  -2.98 |  22.07
# 108 | 110.1 104.0 | -116.68 |  -2.08 | 114.60
# 109 |  87.2  65.8 | -79.50 |  -8.49 |  71.01
# 110 |  69.6  76.3 | -117.08 |  -0.80 | 116.28
# 111 |  72.1  72.9 | -120.06 |  -3.20 | 116.85
# 112 | 107.7 107.4 | -92.49 |  -7.49 |  85.01
# 113 | 114.7  89.7 | -78.77 | -13.79 |  64.98
# 114 | 112.5 100.5 | -60.40 | -13.32 |  47.07
# 115 |  83.6 114.0 | -102.94 |  -4.33 |  98.61
# 116 | 103.9  69.1 | -32.88 |  -3.98 |  28.91
# 117 |  76.1 110.9 | -99.83 |  -3.05 |  96.79
# 118 |  67.2  79.7 | -126.50 |  -6.05 | 120.45
# 119 |  98.1 113.9 | -54.83 |  -8.45 |  46.38
# 120 |  65.7  96.8 | -100.81 |  -4.43 |  96.38
# 121 |  67.5 101.6 | -43.92 |  -7.91 |  36.01
# 122 |  74.6  69.7 | -112.97 |  -0.28 | 112.69
# 123 | 114.3  82.5 | -109.96 |  -7.35 | 102.61
# 124 | 105.2 110.7 | -98.07 |  -2.40 |  95.66
# 125 | 114.7  96.9 | -94.99 | -19.89 |  75.10
# 126 |  64.1  91.8 | -124.61 | -11.48 | 113.13
# 127 |  64.9  83.3 | -78.47 |  -1.43 |  77.03
# 128 |  97.3  65.0 | -130.43 |  -5.19 | 125.24
# 129 |  69.5 106.3 | -135.01 |  -4.14 | 130.86
# 130 |  83.4  64.7 | -97.94 | -11.54 |  86.40
# 131 |  78.9 114.0 | -126.46 |  -6.23 | 120.23
# 132 |  93.4  63.9 | -114.66 |   3.03 | 117.69
# 133 | 101.3  66.0 | -110.45 |   2.05 | 112.50
# 134 |  77.2  66.6 | -114.71 |  -6.00 | 108.71
# 135 | 102.7 113.8 | -78.71 |  -5.20 |  73.51
# 136 | 116.6  86.1 | -58.25 |  -3.73 |  54.53
# 137 |  91.0 116.9 | -116.12 |   0.72 | 116.85
# 138 | 116.8  93.3 | -64.32 |  -4.60 |  59.73
# 139 |  89.6  62.9 | -115.77 |   4.20 | 119.97
# 140 |  86.3 116.9 | -89.56 |  -7.11 |  82.45
# 141 | 111.0  72.3 | -130.44 |  -3.02 | 127.42
# 142 |  71.6 110.7 | -141.29 |  -6.23 | 135.06
# 143 | 113.5  75.6 | -119.37 |  -4.76 | 114.60
# 144 |  95.7 116.9 | -65.44 |   4.42 |  69.87
# 145 |  62.7  86.9 | -105.18 |  -8.77 |  96.41
# 146 | 108.4  69.1 | -122.17 |  -4.06 | 118.11
# 147 | 112.0 107.3 | -100.11 |  -4.46 |  95.65
# 148 |  68.6  71.8 | -113.29 | -17.91 |  95.38
# 149 | 114.4 103.9 | -119.66 |  -0.40 | 119.26
# 150 |  66.1  75.1 | -46.07 | -14.49 |  31.58
# 151 |  63.9 100.3 | -111.36 |   1.16 | 112.53
# 152 |  81.6 116.9 | -54.28 |  -2.97 |  51.31
# 153 | 116.0  79.0 | -111.70 |   0.75 | 112.44
# 154 |  79.7  63.7 | -98.58 |  -3.06 |  95.52
# 155 | 109.6 110.6 | -95.65 |  -1.46 |  94.19
# 156 |  65.8 105.0 | -114.48 |   0.79 | 115.27
# 157 |  71.1  68.6 | -123.47 |  -6.28 | 117.19
# 158 |  62.2  95.4 | -106.66 |  -2.22 | 104.44
# 159 | 105.7  66.1 | -82.13 |  -1.63 |  80.50
# 160 |  74.3 113.9 | -78.93 |  -0.94 |  77.99
# 161 |  85.8  61.9 | -103.72 |  -6.53 |  97.20
# 162 | 116.6 100.4 | -132.45 |  -0.24 | 132.21
# 163 |  63.8  78.5 | -115.76 |  -0.35 | 115.42
# 164 | 100.3 116.8 | -56.14 |   3.88 |  60.02
# 165 | 118.7  89.6 | -85.05 |  -4.89 |  80.16
# 166 | 107.2 113.7 | -131.29 |  -0.31 | 130.98
# 167 |  73.6  65.6 | -124.66 |  -0.06 | 124.61
# 168 |  99.3  62.2 | -121.79 |  -3.61 | 118.18
# 169 | 118.3  82.5 | -123.45 |  -0.02 | 123.42
# 170 |  67.8 109.6 | -105.20 |   1.63 | 106.83
# 171 |  60.7  90.4 | -96.39 |  -0.11 |  96.28
# 172 |  95.5  61.2 | -126.74 | -11.99 | 114.75
# 173 |  61.6  82.0 | -131.58 |   1.56 | 133.14
# 174 | 118.7  96.8 | -21.88 |  -3.47 |  18.41
# 175 |  77.1 116.8 | -118.22 |  -1.32 | 116.90
# 176 | 103.1  63.1 | -120.25 |   3.21 | 123.47
# 177 |  93.4 119.6 | -125.58 |  -4.34 | 121.24
# 178 |  91.8  60.2 | -120.55 |  -1.79 | 118.75
# 179 |  82.1  60.9 | -117.84 |  -0.47 | 117.36
# 180 | 104.7 116.7 | -51.74 |  -4.67 |  47.07
# 181 |  76.2  62.7 | -64.05 |  -8.45 |  55.60
# 182 | 112.6  69.1 | -75.87 |  -8.25 |  67.62
# 183 | 115.1  72.3 | -62.24 | -11.07 |  51.17
# 184 |  97.9 119.6 | -113.57 |  -3.14 | 110.43
# 185 |  70.0 113.7 | -68.25 |  -0.71 |  67.54
# 186 | 120.5  86.0 | -140.03 | -16.40 | 123.63
# 187 | 110.0  66.1 | -112.25 |  -0.83 | 111.42
# 188 |  59.5  85.5 | -120.40 | -10.46 | 109.94
# 189 | 120.7  93.2 | -128.47 |  -0.85 | 127.61
# 190 |  88.1  59.2 | -133.05 |   0.62 | 133.68
# 191 | 117.5  75.5 | -119.97 |  -8.88 | 111.09
# 192 | 116.1 107.2 | -64.79 |  -8.15 |  56.64
# 193 |  65.3  70.6 | -110.55 |  -9.56 | 100.99
# 194 | 113.8 110.5 | -86.36 |  -3.33 |  83.03
# 195 |  63.0  73.9 | -67.62 |  -1.96 |  65.65
# 196 |  67.8  67.5 | -108.14 |  -7.80 | 100.34
# 197 |  64.2 108.3 | -70.31 |  -5.20 |  65.11
# 198 | 118.3 103.8 | -121.03 |  -5.17 | 115.85
# 199 |  58.9  94.0 | -119.95 | -20.60 |  99.36
# 200 | 111.4 113.6 | -116.51 |  -4.74 | 111.77
# 201 | 107.4  63.2 | -71.57 |  -0.97 |  70.60
# 202 |  72.7 116.8 | -113.27 |   6.90 | 120.17
# 203 | 119.9  78.9 | -111.97 |  -2.37 | 109.60
# 204 |  60.7  77.2 | -70.64 |  -8.33 |  62.31
# 205 | 102.3 119.5 | -121.88 |  -5.30 | 116.57
# 206 |  70.3  64.6 | -118.24 |   1.37 | 119.61
# 207 |  78.6  60.0 | -91.70 |  -2.43 |  89.27
# 208 | 120.5 100.3 | -110.38 |  -4.63 | 105.76
# 209 |  84.5  58.3 | -104.56 |  -2.06 | 102.50
# 210 |  97.5  58.6 | -114.24 | -11.02 | 103.22
# 211 | 109.0 116.6 | -120.00 | -11.74 | 108.26
# 212 | 101.1  59.5 | -113.21 | -13.49 |  99.72
# 213 |  66.3 112.6 | -104.89 |  -2.15 | 102.74
# 214 |  57.6  89.1 | -122.82 |  -3.44 | 119.38
# 215 | 122.4  89.5 | -114.40 |   1.45 | 115.85
# 216 |  93.9  57.6 | -97.95 |  -6.97 |  90.97
# 217 |  58.5  80.7 | -142.27 |  -2.08 | 140.18
# 218 |  75.4 119.6 | -81.13 |   0.10 |  81.23
# 219 |  72.8  61.7 | -82.25 |  -7.41 |  74.84
# 220 | 122.0  82.4 | -71.14 |  -9.33 |  61.80
# 221 | 122.4  96.7 | -136.54 |  -1.23 | 135.31
# 222 | 114.0  66.1 | -116.19 |  -4.46 | 111.73
# 223 | 106.5 119.4 | -117.98 |  -3.03 | 114.95
# 224 |  81.0  57.4 | -109.32 |  -9.02 | 100.30
# 225 |  68.5 116.6 | -123.74 |  -1.49 | 122.25
# 226 | 111.4  63.2 | -121.22 |  -3.91 | 117.31
# 227 | 117.6 110.3 | -80.93 |   0.01 |  80.93
# 228 |  56.6  84.2 | -98.51 | -11.86 |  86.65
# 229 |  75.3  59.1 | -118.49 |   2.89 | 121.38
# 230 |  62.3  69.5 | -112.03 |  -6.40 | 105.63
# 231 |  64.7  66.5 | -98.73 |  -6.10 |  92.63
# 232 | 115.3 113.5 | -128.79 |   0.08 | 128.87
# 233 | 119.9 107.1 | -147.02 |  -3.53 | 143.49
# 234 |  60.0  72.7 | -117.10 |  -7.84 | 109.26
# 235 | 124.0  85.9 | -134.02 |  -0.09 | 133.94
# 236 |  86.8  55.9 | -127.35 |  -8.94 | 118.41
# 237 | 124.2  93.1 | -121.04 |  -7.25 | 113.78
# 238 |  67.2  63.6 | -124.51 |  -3.25 | 121.25
# 239 | 112.9 116.5 | -111.22 | -18.08 |  93.14
# 240 | 122.0 103.7 | -122.38 |  -0.92 | 121.46
# 241 |  71.2 119.5 | -91.80 |  -0.93 |  90.87
# 242 |  57.8  76.0 | -117.40 |   0.08 | 117.47
# 243 | 123.4  78.9 | -100.97 | -11.19 |  89.78
# 244 |  69.7  60.8 | -124.12 | -17.96 | 106.15
# 245 |  77.7  56.6 | -105.82 | -14.18 |  91.64
# 246 |  83.4  55.1 | -104.91 |  -6.91 |  98.00
# 247 |  55.8  79.4 | -102.38 |  -1.16 | 101.23
# 248 | 125.8  89.4 | -126.36 |  -4.32 | 122.04
# 249 | 125.4  82.3 | -113.50 |  -1.61 | 111.88
# 250 |  80.1  54.3 | -117.91 | -13.44 | 104.48
# 251 |  74.6  55.8 | -112.04 |  -0.23 | 111.81
# 252 | 127.2  85.8 | -125.55 |  -0.13 | 125.42
# 253 | 127.4  92.9 | -122.11 |  -6.77 | 115.34
# 254 |  77.0  53.5 | -116.14 |   0.72 | 116.86
# 255 | 128.9  89.3 | -119.09 |  -1.37 | 117.72
# Handover simulation:
# [   0 ms] active beam idx=238 (θ=67.2°, φ=63.6°), gain=-11.2 dB, switched=True
# [  50 ms] active beam idx=238 (θ=67.2°, φ=63.6°), gain=-5.6 dB, switched=False
# [ 100 ms] active beam idx=238 (θ=67.2°, φ=63.6°), gain=-12.1 dB, switched=False
# [ 150 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-2.1 dB, switched=True
# [ 200 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-2.4 dB, switched=False
# [ 250 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-2.8 dB, switched=False
# [ 300 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-3.3 dB, switched=False
# [ 350 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-3.8 dB, switched=False
# [ 400 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-4.3 dB, switched=False
# [ 450 ms] active beam idx=244 (θ=69.7°, φ=60.8°), gain=-4.7 dB, switched=False
# [ 500 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=2.1 dB, switched=True
# [ 550 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=0.7 dB, switched=False
# [ 600 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=1.9 dB, switched=False
# [ 650 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=5.1 dB, switched=False
# [ 700 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=5.4 dB, switched=False
# [ 750 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=4.3 dB, switched=False
# [ 800 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=0.9 dB, switched=False
# [ 850 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-1.1 dB, switched=False
# [ 900 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=3.1 dB, switched=False
# [ 950 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-0.3 dB, switched=False
# [1000 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-9.9 dB, switched=False
# [1050 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=1.5 dB, switched=False
# [1100 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=2.3 dB, switched=False
# [1150 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=1.1 dB, switched=False
# [1200 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=2.7 dB, switched=False
# [1250 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=4.9 dB, switched=False
# [1300 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=5.0 dB, switched=False
# [1350 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=2.4 dB, switched=False
# [1400 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-3.5 dB, switched=False
# [1450 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-4.3 dB, switched=False
# [1500 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-0.5 dB, switched=False
# [1550 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=1.0 dB, switched=False
# [1600 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=1.1 dB, switched=False
# [1650 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=0.7 dB, switched=False
# [1700 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=0.0 dB, switched=False
# [1750 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-0.9 dB, switched=False
# [1800 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-1.8 dB, switched=False
# [1850 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-2.4 dB, switched=False
# [1900 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-2.5 dB, switched=False
# [1950 ms] active beam idx=251 (θ=74.6°, φ=55.8°), gain=-2.0 dB, switched=False
